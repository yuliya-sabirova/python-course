# %% [markdown]
# # Лабораторная работа №12: Итоговая работа
# ## Моделирование динамических систем с помощью ОДУ
#
# **ФИО:** _________________________
#
# **Группа:** _______________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_группа_лаб12.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Цель работы
#
# Научиться моделировать динамические системы, описываемые обыкновенными дифференциальными уравнениями (ОДУ). Освоить стандартный программный подход к решению ОДУ (аналитический и численный), визуализировать поведение системы во времени и проанализировать полученные результаты.

# %% [markdown]
# ### Определение номера варианта
#
# Номер варианта соответствует вашему номеру в списке группы. Если в группе более 13 человек, номер варианта вычисляется по формуле: `(N - 1) % 13 + 1`, где `N` — ваш номер в списке.

# %% [markdown]
# ### Таблица вариантов
#
# | № | ОДУ 1-го порядка | ОДУ 2-го порядка |
# |:---:|:---|:---|
# | 1 | $y' + 3y = 6$, $y(0) = 2$. | $y'' + 3y' + 2y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 2 | $y' - y = e^t$, $y(0) = 1$. | $y'' - y = 0$, $y(0) = 1, y'(0) = 1$. |
# | 3 | $y' + y \cos(t) = \sin(t)$, $y(0) = 0$. | $y'' + y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 4 | $y' = t^2 - y$, $y(0) = 1$. | $y'' + 2y' + y = 0$, $y(0) = 1, y'(0) = -1$. |
# | 5 | $y' = y \ln(y)$, $y(1) = e$. | $y'' + y' = 0$, $y(0) = 1, y'(0) = -1$. |
# | 6 | $y' + \frac{2}{t}y = t^3$, $y(1) = 0$. | $y'' - 4y' + 4y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 7 | $y' = e^{-t} - y$, $y(0) = 1$. | $y'' + 4y = 0$, $y(0) = 0, y'(0) = 1$. |
# | 8 | $y' + 2y = t^2$, $y(0) = 1$. | $y'' - 3y' + 2y = e^t$, $y(0) = 0, y'(0) = 1$. |
# | 9 | $y' = y^2 - 2y + 1$, $y(0) = 1$. | $y'' + y = \cos(t)$, $y(0) = 0, y'(0) = 1$. |
# | 10 | $y' - 3y = t$, $y(0) = 0$. | $y'' + 2y' + 5y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 11 | $y' = 1 + y^2$, $y(0) = 0$. | $y'' + y' - 6y = t$, $y(0) = 1, y'(0) = -1$. |
# | 12 | $y' + y = e^t$, $y(0) = 0$. | $y'' - t^2y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 13 | $y' = y \sin(t)$, $y(0) = 1$. | $y'' + 5y' + 6y = \sin(t)$, $y(0) = 0, y'(0) = 1$. |

# %% [markdown]
# ---

# %% [markdown]
# ## Задание 1: Решение и анализ ОДУ по варианту (4 балла)
#
# В этом задании необходимо решить оба уравнения из вашего варианта (первого и второго порядка) двумя способами и сравнить результаты.

# %% [markdown]
# ### 1.1. ОДУ первого порядка (2 балла)
#
# 1.  **Аналитическое решение:** Найдите точное решение с помощью `sympy.dsolve`.
# 2.  **Численное решение:** Найдите численное решение с помощью `scipy.integrate.solve_ivp` на интервале времени `t` от 0 до 5.
# 3.  **Визуализация:** Постройте на одном графике аналитическое (в виде линии) и численное (в виде точек) решения. График должен быть подписан, оси размечены, легенда должна присутствовать.
# 4.  **Вывод:** Сделайте краткий вывод о совпадении решений.

# %%
# Ваш код для Задания 1.1

# %% [markdown]
# **Вывод по Заданию 1.1:**
#
# *(здесь ваш текстовый вывод)*

# %% [markdown]
# ### 1.2. ОДУ второго порядка (2 балла)
#
# 1.  **Преобразование:** Вручную преобразуйте ОДУ второго порядка в систему из двух ОДУ первого порядка. Запишите эту систему в текстовой ячейке ниже.
# 2.  **Аналитическое решение:** Найдите точное решение исходного уравнения с помощью `sympy.dsolve`.
# 3.  **Численное решение:** Решите полученную систему с помощью `scipy.integrate.solve_ivp` на интервале времени `t` от 0 до 10.
# 4.  **Визуализация:** Постройте на одном графике аналитическое и численное решения для `y(t)`.
# 5.  **Вывод:** Сделайте краткий вывод о совпадении решений.

# %% [markdown]
# **Ваша система ОДУ первого порядка:**
# $$ \begin{cases} y_1' = ... \\ y_2' = ... \end{cases} $$

# %%
# Ваш код для Задания 1.2

# %% [markdown]
# **Вывод по Заданию 1.2:**
#
# *(здесь ваш текстовый вывод)*

# %% [markdown]
# ---

# %% [markdown]
# ## Задание 2: Исследование численного метода (3 балла)
#
# В этом задании вы глубже изучите работу решателя `solve_ivp`.

# %% [markdown]
# ### 2.1. Сравнение решателей (1.5 балла)
#
# 1.  Возьмите ваше ОДУ второго порядка из Задания 1.2.
# 2.  Решите его с помощью `solve_ivp` дважды, используя разные методы: `method='RK45'` (используется по умолчанию) и `method='LSODA'` (хорош для "жестких" систем).
# 3.  Постройте оба численных решения на одном графике.
# 4.  **Ответьте на вопросы:** Визуально, есть ли разница в результатах для вашей задачи? В каких случаях выбор метода может быть критически важен?

# %%
# Ваш код для Задания 2.1

# %% [markdown]
# **Ответы на вопросы по Заданию 2.1:**
#
# *(здесь ваши ответы)*

# %% [markdown]
# ### 2.2. Оценка погрешности (1.5 балла)
#
# 1.  Для вашего ОДУ второго порядка (или первого, на выбор) вычислите **абсолютную ошибку** между численным решением (полученным методом `RK45`) и аналитическим решением в каждой точке, где было найдено численное решение.
# 2.  Постройте график зависимости этой ошибки от времени `t`.
# 3.  **Ответьте на вопрос:** В какой части временного интервала ошибка максимальна? Почему, на ваш взгляд, это происходит?

# %%
# Ваш код для Задания 2.2

# %% [markdown]
# **Ответ на вопрос по Заданию 2.2:**
#
# *(здесь ваш ответ)*

# %% [markdown]
# ---

# %% [markdown]
# ## Задание 3: Прикладная задача — Моделирование физической системы (3 балла)
#
# Это творческое, итоговое задание, которое показывает мощь ОДУ. Выберите и решите **одну** из предложенных задач.

# %% [markdown]
# ### Вариант 1: Модель "Хищник-Жертва" (уравнения Лотки-Вольтерры)
#
# Система описывает динамику популяций двух видов: жертв (`x`) и хищников (`y`).
# $$ \begin{cases} dx/dt = a*x - b*x*y \\ dy/dt = -c*y + d*x*y \end{cases} $$
#
# - **Параметры:** `a=1.5, b=0.8, c=1.0, d=0.5`.
# - **Начальные условия:** `x(0) = 2` (2 тыс. жертв), `y(0) = 1` (1 тыс. хищников).
#
# **Что нужно сделать:**
# 1.  Решите эту систему ОДУ на интервале времени `t` от 0 до 20.
# 2.  Постройте график, показывающий изменение популяций `x(t)` и `y(t)` во времени (две кривые на одном графике).
# 3.  Постройте **фазовый портрет**: график зависимости популяции хищников от популяции жертв (`y` от `x`).
# 4.  **Интерпретация:** В текстовой ячейке опишите своими словами, что показывают эти графики. Почему популяции колеблются?

# %% [markdown]
# ### Вариант 2: Модель затухающих колебаний маятника
#
# Линеаризованное уравнение движения маятника с учетом сопротивления воздуха:
# $$ \theta'' + 2\gamma\theta' + \omega^2\theta = 0 $$
# где `θ` - угол отклонения.
#
# - **Параметры:** `ω = 2.0` (собственная частота), `γ = 0.2` (коэффициент затухания).
# - **Начальные условия:** `θ(0) = π/6` (начальный угол 30 градусов), `θ'(0) = 0` (начальная скорость равна нулю).
#
# **Что нужно сделать:**
# 1.  Преобразуйте это ОДУ второго порядка в систему ОДУ первого порядка.
# 2.  Решите систему на интервале времени `t` от 0 до 15.
# 3.  Постройте график зависимости угла `θ(t)` от времени.
# 4.  Постройте **фазовый портрет**: график зависимости угловой скорости `θ'(t)` от угла `θ(t)`.
# 5.  **Интерпретация:** В текстовой ячейке опишите, как затухание влияет на движение маятника, основываясь на полученных графиках. Что показывает фазовый портрет?

# %%
# Ваш код для Задания 3 (выберите один из вариантов)

# %% [markdown]
# **Интерпретация результатов Задания 3:**
#
# *(здесь ваш текстовый вывод)*

# %% [markdown]
# ---

# %% [markdown]
# ### Вопросы для самопроверки
#
# 1.  Чем отличаются аналитическое и численное решения ОДУ?
# 2.  Какие методы численного решения вы использовали и в чем их особенность?
# 3.  Как преобразовать ОДУ высокого порядка в систему первого порядка?
# 4.  Что такое фазовый портрет и что он показывает в вашей прикладной задаче?
