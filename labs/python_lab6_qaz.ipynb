# %% [markdown]
# # №6 Зертханалық жұмыс: Файлдар, лямбда-функциялар және рекурсия
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АТ_мамандық_зерт6.ipynb` форматында болуы керек.
#
# **Жалпы баға:** 20 балл

# %% [markdown]
# ### Жұмысқа аннотация
#
# **Негізгі тақырыптар:** Файлдарды ашу (`open()`), оқу және жазу, `with` контекстік менеджері. `lambda` анонимді функциялары. Рекурсивті функциялар.
#
# **Жұмыс мақсаты:** Бағдарлама жұмысының нәтижелерін тұрақты етуге мүмкіндік беретін файлдардан деректерді сақтауды және оқуды үйрену. Лямбда-функциялар мен рекурсия арқылы бағдарламалаудың жаңа парадигмаларын меңгеру. Файлдық деректерді өңдеу үшін бұрын зерттелген барлық дағдыларды (циклдер, функциялар, деректер құрылымдары) қолдану.

# %% [markdown]
# ## 1-бөлім. Рекурсивті функциялар (4.5 балл)
#
# Бұл бөлімде рекурсияны қолдана отырып, бірнеше классикалық алгоритмді жүзеге асыру қажет. Әр тапсырма 1.5 баллмен бағаланады.

# %% [markdown]
# ### 1.1-тапсырма: Ең үлкен ортақ бөлгіш (ЕҮОБ)
#
# **Мәселе:** Екі бүтін оң санның ең үлкен ортақ бөлгішін табу үшін Евклид алгоритмін қолданатын `NOD(A, B)` рекурсивті функциясын сипаттаңыз:
# - `ЕҮОБ(А, В) = ЕҮОБ(В, А % В)`, егер `В ≠ 0` болса
# - `ЕҮОБ(А, 0) = A`
#
# Осы функцияның көмегімен бірнеше жұп санның ЕҮОБ-ін табыңыз (мысалы, (32, 24), (1024, 64)).

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 1.2-тапсырма: Рекурсивті дәрежеге шығару
#
# **Мәселе:** X санының N-дәрежесін келесі формулалар бойынша табатын `PowerN(X, N)` рекурсивті функциясын сипаттаңыз:
# - $X^0 = 1$;
# - $X^N = (X^{N/2})^2$ егер N жұп және > 0 болса;
# - $X^N = X \cdot X^{N-1}$ егер N тақ және > 0 болса.
#
# Осы функцияның көмегімен бірнеше жұп санның дәрежесін табыңыз (мысалы, (2, 10), (3, 5)).

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 1.3-тапсырма: Қос факториал
#
# **Мәселе:** Қос факториалды есептеу үшін `Fact2(N)` рекурсивті функциясын сипаттаңыз:
# $N!! = N \cdot (N-2) \cdot (N-4) \cdot ...$
#
# Көбейтіндідегі соңғы көбейткіш, егер N — жұп сан болса 2-ге, ал тақ сан болса 1-ге тең. Базалық жағдайлар `Fact2(1)=1` және `Fact2(2)=2` болады.
#
# 5-тен 8-ге дейінгі сандар үшін қос факториалды есептеңіз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ## 2-бөлім. Анонимді функциялар (Lambda) (4.5 балл)
#
# Бұл бөлімде сіз `lambda` функцияларын жоғары ретті функциялармен бірге қолдануды үйренесіз. Әр тапсырма 1.5 баллмен бағаланады.

# %% [markdown]
# ### 2.1-тапсырма: `map` арқылы сандардың квадраттары
#
# **Мәселе:** Сандар тізімі берілген. `lambda` және `map()` көмегімен бастапқы тізімдегі сандардың квадраттарынан тұратын жаңа тізім құрыңыз.

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 2.2-тапсырма: `filter` арқылы тақ сандарды сүзу
#
# **Мәселе:** Сандар тізімі берілген. `lambda` және `filter()` көмегімен тек тақ сандарды сүзіп алыңыз.

# %%
numbers = [10, 23, 44, 51, 60, 75, 80, 99]
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 2.3-тапсырма: Жолдар тізімін ұзындығы бойынша сұрыптау
#
# **Мәселе:** Жолдар тізімі берілген. Осы тізімді `lambda` функциясының көмегімен жолдардың ұзындығының өсуі бойынша сұрыптаңыз.

# %%
words = ["python", "is", "a", "powerful", "language"]
# Сіздің шешіміңіз осында

# %% [markdown]
# ## 3-бөлім. Файлдармен жұмыс (Синтез) (11 балл)
#
# Бұл блок барлық зерттелген тақырыптарды біріктіреді. Сізге файлдардан деректерді оқу, оларды өңдеу және нәтижелерді жазу керек болады.
#
# **Дайындық:** Тапсырмаларды орындамас бұрын, ноутбук орналасқан сол қалтада `data.txt` атты мәтіндік файл құрып, оған келесі мәтінді көшіріңіз:
# ```
# Бұл зертханалық жұмысқа арналған бірінші жол.
# Python - тамаша бағдарламалау тілі.
#
# Файлдармен жұмыс істеу бағдарламалаудың маңызды бөлігі болып табылады.
# Деректерді оқу және жазу қабілеті - табысқа жетудің кілті.
# Табыс көп тәжірибе жасайтындарға келеді.
# ```

# %% [markdown]
# ### 3.1-тапсырма: Файл құру және оған жазу (1 балл)
#
# **Мәселе:** Пайдаланушы енгізген бірнеше мәтін жолын мәтіндік файлға жазатын бағдарлама жазыңыз. Содан кейін файлды оқу үшін ашып, оның мазмұнын экранға шығарыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.2-тапсырма: Жолдарды нөмірлеу (1 балл)
#
# **Мәселе:** `data.txt` файлын оқу үшін ашатын, әр жолды нөмірлеп, нәтижені `numbered_data.txt` жаңа файлына `"N: Бастапқы жол"` форматында жазатын бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.3-тапсырма: Файлды көшіру (1 балл)
#
# **Мәселе:** `data.txt` файлының `data_copy.txt` атты толық көшірмесін жасайтын бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.4-тапсырма: Файлдағы сөздерді санау (нұсқалармен) (1 балл)
#
# **Нұсқаулық:** Сіздің нұсқаңыз `(N - 1) % 4 + 1` формуласы бойынша анықталады, мұндағы `N` — топ тізіміндегі сіздің нөміріңіз. Тек өз нұсқаңызды орындаңыз.
#
# **Мәселе:** `data.txt` файлындағы жалпы және бірегей сөздердің санын нұсқаңызға сәйкес санайтын бағдарлама жазыңыз.
# -   **1-нұсқа:** Қарапайым санау. Сөздер бос орынмен бөлінген. `"Сөз"` және `"сөз"` әртүрлі сөздер болып саналады. Тыныс белгілері сөздің бір бөлігі болып табылады.
# -   **2-нұсқа:** Регистрді есепке алмай санау. `"Сөз"` және `"сөз"` бірдей сөз болып саналады.
# -   **3-нұсқа:** Регистрді және тыныс белгілерін есепке алмай. `"бағдарламалаудың."` және `"бағдарламалаудың"` бірдей сөз болып саналады. (Нүкте, үтір, сызықшаны алып тастаңыз).
# -   **4-нұсқа:** Жетілдірілген санау. 3-нұсқадағыдай, бірақ сөздер тек әріптерден тұруы керек (сандар мен басқа таңбалар ескерілмейді).

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.5-тапсырма: Файлда іздеу және ауыстыру (нұсқалармен) (1 балл)
#
# **Нұсқаулық:** Сіздің нұсқаңыз `(N - 1) % 4 + 1` формуласы бойынша анықталады, мұндағы `N` — топ тізіміндегі сіздің нөміріңіз.
#
# **Мәселе:** Пайдаланушыдан іздеу сөзін және ауыстыру сөзін сұрайтын, содан кейін нұсқаға сәйкес ауыстырылған сөздермен `replaced_data.txt` жаңа файлын жасайтын бағдарлама жазыңыз.
# -   **1-нұсқа:** Регистрді ескере отырып, ішкі жолды қарапайым ауыстыру ( `str.replace()` қолданыңыз).
# -   **2-нұсқа:** Регистрді ескере отырып, тек бүтін сөздерді ауыстыру.
# -   **3-нұсқа:** Регистрді ескермей, ішкі жолды ауыстыру.
# -   **4-нұсқа:** Регистрді ескермей, тек бүтін сөздерді ауыстыру.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.6-тапсырма: Файлдарды біріктіру (1 балл)
#
# **Мәселе:** Тағы екі шағын мәтіндік файл (`add1.txt`, `add2.txt`) құрыңыз. `data.txt`, `add1.txt` және `add2.txt` мазмұнын `merged_data.txt` атты бір қорытынды файлға біріктіретін бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.7-тапсырма: Бос жолдарды жою (1 балл)
#
# **Мәселе:** `data.txt` файлын оқитын және барлық бос жолдарды (тек бос орындардан тұратын жолдарды қоса) жоятын `no_empty_lines_data.txt` көшірмесін жасайтын бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.8-тапсырма: Лог-файлды талдау (нұсқалармен) (2 балл)
#
# **Дайындық:** `logs.txt` файлын келесі мазмұнмен құрыңыз:
# ```
# 2023-10-29 10:00:01 INFO: User 'admin' logged in.
# 2023-10-29 10:01:15 INFO: Data processing started.
# 2023-10-29 10:02:30 WARNING: Disk space is running low.
# 2023-10-29 10:03:00 ERROR: Failed to connect to database.
# 2023-10-29 10:05:45 INFO: Data processing finished.
# 2023-10-29 10:06:21 ERROR: Module 'payment' failed with timeout.
# ```
# **Нұсқаулық:** Сіздің нұсқаңыз `(N - 1) % 4 + 1` формуласы бойынша анықталады.
#
# **Мәселе:** Осы лог-файлды талдауға арналған бағдарлама жазыңыз.
# -   **1-нұсқа:** Әрбір қателік деңгейі (INFO, WARNING, ERROR) үшін жазбалар санын санап, шығарыңыз.
# -   **2-нұсқа:** Экранға тек `ERROR` деңгейін қамтитын жолдарды шығарыңыз.
# -   **3-нұсқа:** `WARNING` деңгейіндегі барлық оқиғалардың уақытын (`СС:ММ:СС` форматында) тауып, шығарыңыз.
# -   **4-нұсқа:** 10-шы сағатта (10:00:00-ден 10:59:59-ға дейін) барлығы қанша оқиға болғанын санаңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3.9-тапсырма: CSV-файлмен жұмыс (2 балл)
#
# **Дайындық:** `students.csv` (CSV - Comma-Separated Values) файлын келесі мазмұнмен құрыңыз:
# ```
# Name,Age,Course
# Ardak,27,3
# Bekarys,23,2
# Aliya,30,4
# ```
# **Мәселе:** Келесі әрекеттерді орындайтын бағдарлама жазыңыз:
# 1. `students.csv` файлынан деректерді оқиды.
# 2. Пайдаланушыдан жаңа студенттің атын, жасын және курсын сұрайды.
# 3. `students.csv` файлының соңына жаңа жазбаны қосады.
# 4. Файлдың қорытынды мазмұнын экранға шығарады.

# %%
# Сіздің шешіміңіз осында
