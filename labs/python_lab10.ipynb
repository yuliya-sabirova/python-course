# %% [markdown]
# # Лабораторная работа №10: Основы Pandas
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб10.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Цель работы
# Научиться работать с табличными данными — наиболее распространенным форматом данных в аналитике. Освоить загрузку, осмотр, базовую фильтрацию и сортировку данных с помощью библиотеки Pandas.

# %% [markdown]
# ## Часть 1: Разминка на датасете `mpg.csv` (3 балла)
#
# В этой части вы отработаете базовые навыки на датасете с характеристиками автомобилей.

# %% [markdown]
# ### Задание 1.1: Загрузка и первичный осмотр (1 балл)
#
# 1.  Импортируйте Pandas как `pd`.
# 2.  Загрузите датасет `mpg.csv` в DataFrame под названием `df`.
#     > **Важно:** В столбце `horsepower` есть некорректные значения в виде `'?'`. Чтобы Pandas корректно их распознал как пропуски, используйте параметр `na_values='?'` в функции `pd.read_csv()`.
# 3.  Выведите первые 5 строк.
# 4.  Выведите размерность DataFrame.
# 5.  Выведите общую информацию о DataFrame, обратив внимание на типы данных и наличие пропусков в столбце `horsepower`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 1.2: Фильтрация и создание столбцов (2 балла)
#
# 1.  Создайте новый столбец `weight_kg`, который будет содержать вес автомобиля в килограммах. Используйте формулу: 1 фунт = 0.453592 кг. Округлите результат до 2 знаков после запятой.
# 2.  Создайте DataFrame `american_powerful_cars`, который содержит автомобили, удовлетворяющие ВСЕМ трем условиям:
#     *   `origin` равен 1 (Американские)
#     *   `cylinders` равен 8
#     *   `horsepower` больше 150
# 3.  Отсортируйте `american_powerful_cars` по `horsepower` по убыванию и выведите первые 5 строк.

# %%
# Ваш код здесь

# %% [markdown]
# ## Часть 2: Основное задание на датасете `hotel_booking_data.csv` (7 баллов)

# %% [markdown]
# ### Задание 2.1: Загрузка и первичный осмотр (1 балл)
#
# 1. Загрузите файл `hotel_booking_data.csv` в DataFrame с именем `hotels`.
# 2. Выведите первые 7 строк DataFrame.
# 3. Выведите общую информацию о DataFrame с помощью метода `.info()`. Есть ли в данных пропуски?

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2.2: Работа со столбцами (1.5 балла)
#
# 1. Создайте новый столбец `total_nights`, который будет являться суммой столбцов `stays_in_weekend_nights` и `stays_in_week_nights`.
# 2. Создайте столбец `total_guests`, который будет суммой `adults`, `children` и `babies`.
# 3. Удалите столбцы `name`, `email`, `phone-number` и `credit_card` из DataFrame `hotels`.
# 4. Выведите `.head()` обновленного DataFrame.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2.3: Фильтрация данных (2.0 балла)
#
# 1. Сколько бронирований было отменено (`is_canceled` == 1)?
# 2. Создайте DataFrame `resort_bookings`, содержащий только бронирования для `Resort Hotel`.
# 3. Создайте DataFrame `long_stay_bookings`, содержащий бронирования, где `total_nights` больше 10.
# 4. Создайте DataFrame `vip_bookings`, содержащий бронирования для `City Hotel`, где `total_guests` > 3 и `total_of_special_requests` > 0. Сколько таких бронирований?

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2.4: Анализ категорий и сортировка (2.5 балла)
#
# 1. Какая страна (`country`) встречается чаще всего среди всех бронирований?
# 2. Сколько бронирований было сделано в каждом из сегментов рынка (`market_segment`)? (Используйте `.value_counts()`)
# 3. Найдите 5 самых дорогих бронирований (по `adr` - средней цене за номер).
# 4. **(Комплексная задача)** Найдите **среднюю цену за ночь на одного гостя** (`adr` / `total_guests`) для всех **не отмененных** бронирований в `Resort Hotel`, где было **больше двух** специальных запросов (`total_of_special_requests > 2`).

# %%
# Ваш код здесь
