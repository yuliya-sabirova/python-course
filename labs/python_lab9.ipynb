# %% [markdown]
# # Лабораторная работа №9: NumPy: Векторные вычисления и линейная алгебра
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб9.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Цель работы:** Освоить NumPy как фундаментальный инструмент для научных и инженерных вычислений в Python, начиная от создания базовых массивов и заканчивая решением классических задач линейной алгебры. Понять ключевые преимущества векторизованных вычислений для быстрой обработки больших объемов числовых данных.

# %% [markdown]
# ### Определение номера варианта
#
# Ваш вариант для заданий, где это указано, вычисляется по формуле: **`(N - 1) % 4 + 1`**, где `N` — ваш номер в списке группы.

# %% [markdown]
# ## Часть 1. Основы NumPy (4 балла)

# %% [markdown]
# ### Задание 1: Создание массивов (1 балл)
#
# 1.  Создайте одномерный массив `arr1` из чисел от 1 до 20 включительно.
# 2.  Преобразуйте `arr1` в матрицу `matrix1` размером 4x5.
# 3.  Создайте массив `arr2` из 15 равномерно распределенных значений в диапазоне [0, 10] c помощью `np.linspace()`.
# 4.  Создайте диагональную матрицу `matrix2` 4x4 с элементами [1, 2, 3, 4] на главной диагонали.
# 5.  Создайте матрицу `matrix3` размером 3x3, заполненную случайными целыми числами в диапазоне [1, 10].

# %%
import numpy as np

# Ваше решение здесь

# %% [markdown]
# ### Задание 2: Индексация и срезы (1 балл)
#
# Дан массив `data = np.arange(1, 37).reshape(6, 6)`. Выполните следующие операции:
# 1.  Извлеките элемент, который находится в 4-й строке и 2-м столбце.
# 2.  Извлеките всю третью строку массива.
# 3.  Извлеките весь пятый столбец массива.
# 4.  Извлеките подматрицу 3x3 из левого нижнего угла.

# %%
data = np.arange(1, 37).reshape(6, 6)

# Ваше решение здесь

# %% [markdown]
# ### Задание 3: Условная фильтрация и агрегация (1 балл)
#
# 1.  Создайте матрицу `random_matrix` размером 5x5 со случайными целыми числами от 1 до 100.
# 2.  Найдите все элементы, которые больше 50.
# 3.  Найдите сумму всех элементов, которые делятся на 3 без остатка.
# 4.  Найдите среднее значение элементов в каждом столбце (по оси 0).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 4: Транспонирование (1 балл)
#
# 1. Создайте матрицу `non_square_matrix` размером 3x5 со случайными числами.
# 2. Выведите на экран исходную матрицу и ее форму (`.shape`).
# 3. Транспонируйте матрицу.
# 4. Выведите на экран транспонированную матрицу и ее новую форму.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Часть 2. Линейная алгебра (6 баллов)

# %% [markdown]
# ### Задание 5: Матричные операции (2 балла)
#
# **Задача:** Выполните задание согласно вашему варианту.
#
# -   **Вариант 1:** Даны матрицы `A = np.array([[1, -1, 1], [1, 1, 1], [1, 2, 3]])` и `B = np.array([[1, 2, 3], [3, 2, 1], [2, 1, 3]])`.
#     1.  Найдите их матричное произведение `A @ B` тремя разными способами.
#     2.  Найдите определитель и обратную матрицу для `A`.
#     3.  Выполните операцию вещания: умножьте матрицу `A` на скаляр `2` и к каждой строке результата прибавьте вектор `v = np.array([10, 20, 30])`.
#
# -   **Вариант 2:** Даны матрицы `A = np.array([[2, 1, 3], [1, 1, 2], [3, 2, 4]])` и `B = np.array([[1, 0, 1], [2, 1, 1], [0, 1, 2]])`.
#     1.  Найдите их матричное произведение `A @ B` тремя разными способами.
#     2.  Найдите определитель и обратную матрицу для `B`.
#     3.  Выполните операцию вещания: умножьте матрицу `B` на скаляр `3` и к каждой строке результата прибавьте вектор `v = np.array([-1, 0, 1])`.
#
# -   **Вариант 3:** Даны матрицы `A = np.array([[1, 2, 3], [4, 5, 6], [7, 8, 0]])` и `B = np.array([[1, 1, 1], [1, 2, 3], [1, 3, 6]])`.
#     1.  Найдите их матричное произведение `A @ B` тремя разными способами.
#     2.  Найдите определитель и обратную матрицу для `A`.
#     3.  Выполните операцию вещания: умножьте матрицу `A` на скаляр `0.5` и к каждой строке результата прибавьте вектор `v = np.array([5, 5, 5])`.
#
# -   **Вариант 4:** Даны матрицы `A = np.array([[1, 1, 2], [1, 2, 1], [2, 1, 1]])` и `B = np.array([[3, 0, 1], [2, 1, 0], [1, 0, 3]])`.
#     1.  Найдите их матричное произведение `A @ B` тремя разными способами.
#     2.  Найдите определитель и обратную матрицу для `B`.
#     3.  Выполните операцию вещания: умножьте матрицу `B` на скаляр `-1` и к каждой строке результата прибавьте вектор `v = np.array([100, 100, 100])`.

# %%
# Ваше решение здесь (не забудьте указать номер варианта)

# %% [markdown]
# ### Задание 6: Решение СЛАУ (2 балла)
#
# **Задача:** Решите две системы линейных алгебраических уравнений согласно вашему варианту. Обязательно выполните проверку для каждого решения.
#
# **Вариант 1:**
# ```
# 1) 2x₁ - 3x₂ - x₃ = 3      2) x₁ - x₂ - x₃ + x₄ = 0
#    3x₁ + x₂ + 2x₃ = 1         x₁ + x₂ + x₃ - x₄ = 4
#    x₁ + 4x₂ - 2x₃ = -6        x₁ + x₂ - x₃ + x₄ = 6
#                              x₁ - x₂ + x₃ + x₄ = 2
# ```
#
# **Вариант 2:**
# ```
# 1) x₁ + 2x₂ + 3x₃ = 6      2) 2x₁ + x₂ + x₃ + x₄ = 1
#    4x₁ + 5x₂ + 6x₃ = 9         x₁ + 2x₂ + x₃ + x₄ = 2
#    7x₁ + 8x₂ = -6             x₁ + x₂ + 2x₃ + x₄ = 3
#                              x₁ + x₂ + x₃ + 2x₄ = 4
# ```
#
# **Вариант 3:**
# ```
# 1) x₁ + 2x₂ + 3x₃ = 1      2) 2x₁ + x₂ + x₃ + x₄ = 2
#    x₂ + 2x₃ + 3x₄ = 2         x₁ + 2x₂ + x₃ + x₄ = 1
#    x₃ + 2x₄ = 3             x₁ + x₂ + 2x₃ + x₄ = 2
#    x₁ + x₂ + x₃ + x₄ = 4        x₁ + x₂ + x₃ + 2x₄ = 1
# ```
#
# **Вариант 4:**
# ```
# 1) x₁ + 2x₂ - x₃ = 2       2) x₁ + 2x₂ + 3x₃ - 2x₄ = 6
#    2x₁ - x₂ + x₃ = 3         2x₁ - x₂ - 2x₃ - 3x₄ = 8
#    x₂ + 2x₃ = -2             3x₁ + 2x₂ - x₃ + 2x₄ = 4
#                              2x₁ - 3x₂ + 2x₃ + x₄ = -8
# ```

# %%
# Ваше решение здесь (не забудьте указать номер варианта)

# %% [markdown]
# ### Задание 7: Решение матричного уравнения (2 балла)
#
# **Задача:** Решите матричное уравнение согласно вашему варианту и выполните проверку.
#
# -   **Вариант 1:** `AX = B`
#     `A = np.array([[1, 2], [3, -1]])`, `B = np.array([[4, -1], [2, 5]])`
#
# -   **Вариант 2:** `XA = B`
#     `A = np.array([[1, 2, -1], [2, -1, 1], [-1, 2, 1]])`, `B = np.array([[1, -2, 1], [2, -1, 1], [-1, 2, 1]])`
#
# -   **Вариант 3:** `AX = B`
#     `A = np.array([[3, -1], [5, -2]])`, `B = np.array([[14, 16], [9, 10]])`
#
# -   **Вариант 4:** `XA = B`
#     `A = np.array([[5, 3, 1], [1, -3, -2], [-5, 2, 1]])`, `B = np.array([[-8, 3, 0], [-5, 9, 0], [-2, 15, 0]])`
#
# > **Подсказка:** Для уравнения `XA = B`, решение будет `X = B @ A⁻¹`. Для `AX = B`, решение `X = A⁻¹ @ B`. Порядок умножения важен!

# %%
# Ваше решение здесь (не забудьте указать номер варианта)
