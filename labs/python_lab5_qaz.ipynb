# %% [markdown]
# # №5 Зертханалық жұмыс: Функциялар — тәжірибе
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АТ_мамандық_зерт5.ipynb` форматында болуы керек.
#
# **Жалпы баға:** 20 балл

# %% [markdown]
# ### Жұмысқа аннотация
#
# **Жұмыстың мақсаты:** Күрделі тапсырмаларды функциялар түрінде ресімдей отырып, қарапайым кіші тапсырмаларға декомпозициялауды (бөлуді) үйрену. Функцияларды анықтау (`def`), аргументтерді беру және мәндерді қайтару (`return`) синтаксисін меңгеру. Нәтиже қайтаратын функциялар мен жай ғана әрекеттерді орындайтын процедуралар арасындағы айырмашылықты түсіну.

# %% [markdown]
# ### Орындау тәртібі
#
# Бұл жұмыста сізге 10 тапсырманы шешу керек. Әрбір тапсырманың күрделілігіне және қамтитын тұжырымдамаларына байланысты әртүрлі баллмен бағаланады.
#
# **Баллдарды бөлу:**
# - 1-тапсырма: 1.5 балл
# - 2-тапсырма: 1.5 балл
# - 3-тапсырма: 2.5 балл
# - 4-тапсырма: 1.5 балл
# - 5-тапсырма: 2.5 балл
# - 6-тапсырма: 2.0 балл
# - 7-тапсырма: 2.0 балл
# - 8-тапсырма: 2.5 балл
# - 9-тапсырма: 2.5 балл
# - 10-тапсырма: 1.5 балл
#
# **Жалпы: 20 балл**

# %% [markdown]
# ### 1-тапсырма. Екі ең үлкен санның көбейтіндісі (1.5 балл)
#
# **Мәселе:** Пайдаланушы енгізген үш санды қабылдап, олардың ең үлкен екеуінің көбейтіндісін қайтаратын функция жазу.
#
# **Білу керек:** `if/elif/else`, `min()`, `max()`, функция құру, `return`.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 2-тапсырма. Кездейсоқ тізім генераторы (1.5 балл)
#
# **Мәселе:** Берілген өлшемдегі, кездейсоқ сандармен толтырылған тізімді қайтаратын функция жазу.
#
# **Білу керек:** `import random`, `random.randint()`, циклдер, функция құру, параметрлерді беру.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3-тапсырма. Тізімде бар-жоғын тексеру (2.5 балл)
#
# **Мәселе:** Пайдаланушы 'stop' деп енгізгенше тізімге элементтер қосатын бағдарлама жазу. Осыдан кейін пайдаланушы тексеру үшін сан енгізеді, ал бағдарлама жеке функция арқылы бұл санның тізімде бар-жоғын тексеріп, `True` немесе `False` деп шығарады.
#
# **Білу керек:** `while`, тізім әдістері, `in` операторы, функция құру.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 4-тапсырма. Факториал (1.5 балл)
#
# **Мәселе:** Санның факториалын есептеуге арналған функция жазу. Кіріктірілген `math.factorial` функциясын пайдалануға **тыйым салынады**.
#
# **Білу керек:** Функция құру, циклдер, факториал формуласы ($n! = 1 \cdot 2 \cdot ... \cdot n$, $0! = 1$).

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 5-тапсырма. Фибоначчи сандары (`return`-сыз) (2.5 балл)
#
# **Мақсат:** Мән қайтаратын функция (`return`) мен жай ғана әрекеттерді орындайтын процедураның (мысалы, `print`) айырмашылығын түсіну.
#
# **Мәселе:** Берілген `N`-ге дейінгі Фибоначчи сандарының тізбегін, олардың санын және қосындысын **басып шығаратын** функция жазу. Бұл функцияда `return` операторын қолдануға **тыйым салынады**.
#
# **Айырмашылық мысалы:**
# ```python
# # Процедура (жай басып шығарады)
# def proc(n):
#     print(n)
# proc(5) # Экранда: 5
#
# # Функция (мән қайтарады)
# def func(n):
#     return n
# result = func(5) # result айнымалысында енді 5 мәні сақтаулы
# print(result)    # Экранда: 5
# ```
#
# **Білу керек:** Фибоначчи тізбегі, шартты операторлар, циклдер, `print` пен `return` айырмашылығы.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 6-тапсырма. Жолды форматтау (2.0 балл)
#
# **Мәселе:** Кіріс ретінде жолды, бөлгішті және соңғы таңбаны қабылдайтын функция жазу. Функция жолды бөлгіш бойынша бөліп, әр бөлікке көрсетілген соңғы таңбаны қосып шығаруы керек.
#
# **Шығару мысалы:**
# ```
# # Шақыру: my_func('Қандай керемет әсерлі эликсир', 'й', '+\n')
# Қанда+
# керемет+
# әсерлі+
# эликсир+
# ```
#
# **Білу керек:** Жол әдістері, `return`-сыз функция, `print()` функциясының `sep` және `end` параметрлері.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 7-тапсырма. Сөздікті жаңарту (2.0 балл)
#
# **Мәселе:** Сөздік пен тізімді қабылдайтын функция жазу. Функция бастапқы сөздіктің мәндері тізімдегі мәндермен алмастырылған жаңа сөздікті қайтаруы керек. Элементтер саны сәйкес келеді деп есептеледі.
#
# **Мысал:**
# ```python
# d = {1:2, 3:4}
# l =
# # Нәтиже: {1:5, 3:6}
# ```
#
# **Білу керек:** Сөздіктермен, тізімдермен, циклдермен жұмыс.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 8-тапсырма. Кортеж элементтерінің қосындысы (2.5 балл)
#
# **Мақсат:** Функцияларда **әдепкі аргументтерді** қолдануды үйрену.
#
# **Мәселе:** Сандары бар кортежді қабылдайтын функция жазу. Функция нөлден үлкен және 7-ге қалдықсыз бөлінетін элементтердің қосындысын қайтарады. Егер кортеж берілмесе, функция 1-ден 10-ға дейінгі натурал сандар кортежін пайдалануы керек.
#
# **Білу керек:** Шартты оператор (`if`, `and`), циклдер, **әдепкі аргументтер**.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 9-тапсырма. Кортеж элементтерінің көбейтіндісі (2.5 балл)
#
# **Мақсат:** **Әдепкі аргументтерді** қолдануды бекіту.
#
# **Мәселе:** Сандары бар кортежді қабылдайтын функция жазу. Функция нөлден кіші немесе 3-ке қалдықсыз бөлінетін элементтердің көбейтіндісін қайтарады. Егер кортеж берілмесе, функция 1-ден 10-ға дейінгі натурал сандар кортежін пайдалануы керек.
#
# **Білу керек:** Шартты оператор (`if`, `or`), циклдер, **әдепкі аргументтер**.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 10-тапсырма. Түстерді араластыру (1.5 балл)
#
# **Мәселе:** Екі негізгі түсті ("қызыл", "көк", "сары") қабылдайтын функция жазу. Функция араластыру нәтижесінде пайда болатын екінші деңгейлі түсті немесе қате түстер енгізілсе, қате туралы хабарламаны қайтаруы керек.
#
# **Араластыру ережелері:**
# - қызыл + көк = күлгін
# - қызыл + сары = қызғылт сары
# - көк + сары = жасыл
# - Егер бірдей түстерді араластырса, сол түс шығады.
#
# **Білу керек:** Шартты оператор (`if/elif/else`), функцияға аргументтерді беру.

# %%
# Сіздің шешіміңіз осында
