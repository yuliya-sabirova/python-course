# %% [markdown]
# # Лабораторная работа №11: Численное и символьное интегрирование
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб11.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Цель работы:** Научиться решать задачи интегрального исчисления в Python, понимая разницу между численным (приближенным) и символьным (точным) подходами. Освоить соответствующие инструменты из библиотек `SciPy` и `SymPy` для решения неопределенных, определенных, несобственных и кратных интегралов.

# %% [markdown]
# ### Определение номера варианта
#
# Ваш вариант для каждого задания вычисляется по формуле: **`(N - 1) % M + K`**, где:
# - `N` — ваш номер в списке группы.
# - `M` — количество вариантов в задании.
# - `K` — номер первого варианта в списке.

# %% [markdown]
# ### Контрольные вопросы
#
# При защите работы будьте готовы ответить на следующие вопросы:
# 1.  Чем отличаются аналитические и численные методы интегрирования?
# 2.  Как работает метод трапеций? В чем его основная идея?
# 3.  Какой порядок аргументов и пределов интегрирования используется в функциях `dblquad` и `tplquad` из SciPy?

# %% [markdown]
# ---

# %% [markdown]
# ## Задание 1: Неопределенный интеграл (2 балла)
#
# **Задача:** Выберите **два** варианта интеграла. Найдите их первообразные (неопределенные интегралы), используя библиотеку `SymPy`.

# %% [markdown]
# **Вариант 2126:** $$\int \frac{dx}{x^6(1+x^2)}$$
# **Вариант 2128:** $$\int \frac{dx}{1+x^4+x^8}$$
# **Вариант 2130:** $$\int x^2\sqrt{\frac{x}{1-x}} \,dx$$
# **Вариант 2132:** $$\int \frac{x}{\sqrt{1-x\sqrt{x}}} \,dx$$
# **Вариант 2137:** $$\int \frac{1+\sqrt{1-x^2}}{1-\sqrt{1-x^2}} \,dx$$
# **Вариант 2141:** $$\int x \ln(4+x^4) \,dx$$
# **Вариант 2153:** $$\int \frac{\sin(2x)}{\sqrt{1+\cos^4(x)}} \,dx$$
# **Вариант 2162:** $$\int \frac{\text{arctg}(e^x)}{e^x(1+e^{2x})} \,dx$$

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 2: Определенный интеграл (Комплексное) (3 балла)
#
# **Задача:** Выберите **один** вариант интеграла.
#
# 1.  **Аналитическое решение:** Найдите точное значение интеграла самостоятельно в тетради.
# 2.  **Численное решение (SciPy):** Вычислите значение интеграла с помощью `scipy.integrate.quad`.
# 3.  **Численное решение (своя функция):** Напишите собственные функции для вычисления интеграла методом **трапеций** и методом **Симпсона**.
# 4.  **Сравнение:** Сравните все полученные численные результаты с аналитическим решением.

# %% [markdown]
# **Вариант 2206:** $$\int_{-1}^{8} \sqrt[3]{x} \,dx$$
# **Вариант 2207:** $$\int_{0}^{\pi} \sin(x) \,dx$$
# **Вариант 2208:** $$\int_{1/\sqrt{3}}^{\sqrt{3}} \frac{dx}{1+x^2}$$
# **Вариант 2209:** $$\int_{-1/2}^{1/2} \frac{dx}{\sqrt{1-x^2}}$$
# **Вариант 2211:** $$\int_{0}^{2} |1-x| \,dx$$

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 3: Несобственный интеграл (2 балла)
#
# **Задача:** Выберите **один** вариант. Вычислите несобственный интеграл с помощью `scipy.integrate.quad`. Объясните полученный результат (сходится ли интеграл, и если да, то к какому значению).

# %% [markdown]
# **Вариант (стр. 7, №1):** $$\int_{-\infty}^{0} \frac{dx}{x^2+2x+2}$$
# **Вариант (стр. 7, №2):** $$\int_{-\infty}^{+\infty} \frac{dx}{1+x^2}$$
# **Вариант (стр. 8, №1):** $$\int_{1}^{+\infty} \frac{2+\cos(x)}{\sqrt{x}} \,dx$$
# **Вариант (стр. 8, №2):** $$\int_{e}^{+\infty} \frac{dx}{x\ln(x)}$$
# **Вариант (стр. 8, №3):** $$\int_{0}^{\infty} \cos(x) \,dx$$
# **Вариант (стр. 8, №6):** $$\int_{0}^{+\infty} e^x \,dx$$

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 4: Прикладные задачи (Площадь или Объем) (1.5 балла)
#
# **Задача:** Выберите **одну** задачу на нахождение площади фигуры или объема тела и решите ее с помощью `scipy.integrate.quad`.

# %% [markdown]
# #### Найти площадь фигуры, ограниченной кривыми:
# **Вариант 2397:** $ax = y^2$, $ay = x^2$
# **Вариант 2398:** $y = x^2$, $x + y = 2$
# **Вариант 2399:** $y = 2x - x^2$, $x + y = 0$
#
# #### Найти объем тела:
# **Вариант 2456:** Найти объем чердака, основание которого есть прямоугольник со сторонами `a` и `b`, верхнее ребро равно `c`, а высота равна `h`.
# **Вариант 2457:** Найти объем обелиска, параллельные основания которого суть прямоугольники со сторонами `A, B` и `a, b`, а высота равна `h`.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 5: Кратные интегралы (1.5 балла)
#
# **Задача:** Выберите **один** вариант. Вычислите двойной или тройной интеграл с помощью `scipy.integrate.dblquad` или `scipy.integrate.tplquad`.

# %% [markdown]
# **Вариант (стр. 5, №1):** $$\int_{0}^{1} dx \int_{0}^{1-x} dy \int_{0}^{1-x-y} (x+y+z) \,dz$$
# **Вариант (стр. 6, №7):** $$\int_{0}^{1} dx \int_{0}^{\sqrt{1-x^2}} dy \int_{0}^{\sqrt{1-x^2-y^2}} (x^2+y^2+z^2) \,dz$$
# **Вариант (стр. 7, №4077):** $$\iiint_{V} \frac{dxdydz}{(1+x+y+z)^3}$$, где V ограничена $x+y+z=1$, $x=0$, $y=0$, $z=0$.

# %%
# Ваше решение здесь
