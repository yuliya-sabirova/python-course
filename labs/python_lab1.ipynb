# %% [markdown]
# # Лабораторная работа №1: Основы и работа с текстом
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб1.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ## Часть 1. Базовые операции (4 балла)
#
# В этой части вы должны продемонстрировать умение работать с переменными, вводом-выводом и базовыми арифметическими операциями.

# %% [markdown]
# ### Задание 1. Приветствие и расчет возраста (1 балл)
#
# **Цель:** Написать программу, которая:
# 1. Запрашивает у пользователя его имя.
# 2. Запрашивает у пользователя его год рождения.
# 3. Выводит приветственное сообщение с именем пользователя.
# 4. Рассчитывает и выводит на экран примерный возраст пользователя.
#
# **Пример ввода:**
# ```
# Введите ваше имя: Алиса
# Введите ваш год рождения: 2003
# ```
#
# **Пример вывода:**
# ```
# Привет, Алиса!
# В этом году вам исполнится примерно 21 лет.
# ```

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 2. Простой калькулятор площади (1.5 балла)
#
# **Цель:** Написать программу, которая вычисляет площадь и периметр прямоугольника.
# 1. Запросите у пользователя длину и ширину прямоугольника (могут быть дробными числами).
# 2. Вычислите площадь по формуле: `Площадь = Длина * Ширина`.
# 3. Вычислите периметр по формуле: `Периметр = 2 * (Длина + Ширина)`.
# 4. Выведите результаты на экран с поясняющими надписями.
#
# **Пример ввода:**
# ```
# Введите длину прямоугольника: 5.5
# Введите ширину прямоугольника: 3.2
# ```
#
# **Пример вывода:**
# ```
# Площадь прямоугольника: 17.6
# Периметр прямоугольника: 17.4
# ```

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3. Целочисленная арифметика (1.5 балла)
#
# **Цель:** Написать программу, которая работает с целочисленным делением и остатком.
# 1. Представьте, что у вас есть `N` яблок, которые нужно раздать `K` студентам.
# 2. Запросите у пользователя количество яблок и количество студентов (целые числа).
# 3. Посчитайте, сколько яблок достанется каждому студенту.
# 4. Посчитайте, сколько яблок останется в корзине.
# 5. Выведите результаты на экран.
#
# **Пример ввода:**
# ```
# Сколько яблок в корзине? 50
# Сколько студентов в группе? 7
# ```
#
# **Пример вывода:**
# ```
# Каждый студент получит по 7 яблок.
# В корзине останется 1 яблок.
# ```

# %%
# Ваше решение здесь

# %% [markdown]
# ## Часть 2. Работа со строками (6 баллов)
#
# В этой части проверяются ваши навыки по обработке текстовых данных.

# %% [markdown]
# ### Задание 4. Генератор аккаунта (2 балла)
# **Задача:** Написать программу, которая создает уникальный идентификатор пользователя.
# 1. Запросить у пользователя **Имя**, **Фамилию** и **год рождения**.
# 2. Создать идентификатор, состоящий из:
#    - Первых 3-х букв имени.
#    - Первых 3-х букв фамилии.
#    - Последних 2-х цифр года рождения.
# 3. Весь идентификатор должен быть в нижнем регистре.
# 4. Вывести результат.
#
# **Пример ввода:**
# ```
# Ваше имя: Кайрат
# Ваша фамилия: Айбеков
# Год рождения: 2005
# ```
#
# **Пример вывода:**
# ```
# Полное имя: Кайрат Айбеков
# Аккаунт: кайайб05
# ```

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 5. Создание логина (2 балла)
#
# **Цель:** Написать программу, которая генерирует логин из email.
# 1. Запросите у пользователя его email (например, `user.name@example.com`).
# 2. Извлеките часть строки до символа `@`.
# 3. Замените в полученной части все точки `.` на символы нижнего подчеркивания `_`.
# 4. Выведите полученный логин в нижнем регистре.
#
# **Пример ввода:**
# ```
# Введите ваш email: John.Doe@google.com
# ```
#
# **Пример вывода:**
# ```
# Ваш логин: john_doe
# ```

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 6. Реверс слова (2 балла)
#
# **Цель:** Написать программу, которая переворачивает введенное слово и анализирует его.
# 1. Запросите у пользователя одно слово.
# 2. Переверните это слово, используя срез.
# 3. Выведите перевернутое слово.
# 4. Выведите первый и последний символы **исходного** слова.
#
# **Пример ввода:**
# ```
# Введите слово: программирование
# ```
#
# **Пример вывода:**
# ```
# Слово наоборот: еивораинммаргорп
# Первый символ: П
# Последний символ: е
# ```

# %%
# Ваше решение здесь
