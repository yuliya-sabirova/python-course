# %% [markdown]
# # №7 Зертханалық жұмыс: Python-дағы ОББ негіздері
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АТ_мамандық_зерт7.ipynb` форматында болуы керек.
#
# **Жалпы баға:** 10 балл

# %% [markdown]
# ### Жұмысқа аннотация
#
# **Жұмыс мақсаты:** Жаңа бағдарламалау парадигмасы — ОББ-мен танысу. Деректер мен мінез-құлықты біріктіретін объектілер тұрғысынан ойлауды үйрену. Алғашқы класстарды құрып, оларда ОББ-ның негізгі қағидаларын: инкапсуляция, мұрагерлік және полиморфизмді кезең-кезеңімен жүзеге асыру.

# %% [markdown]
# ### Теориялық бөлім:
#
# Жұмысты бастамас бұрын, келесі терминдерді түсінетініңізге көз жеткізіңіз:
# -   **Класс және объект**
# -   **Атрибуттар және әдістер**
# -   **Инкапсуляция**
# -   **Мұрагерлік**
# -   **Полиморфизм**
# -   **Абстрактілі класс**

# %% [markdown]
# ## Тапсырмалар
# Бұл жұмыс біртұтас кезеңдік жоба болып табылады, мұнда әрбір келесі тапсырма алдыңғысын толықтырады. Әр тапсырма 2 баллмен бағаланады.

# %% [markdown]
# ### 1-тапсырма: Базалық классты құру (2 балл)
#
# 1.  Адамды білдіретін `Person` класын құрыңыз.
# 2.  `__init__` конструкторында екі атрибутты анықтаңыз: `name` (аты) және `age` (жасы).
# 3.  `"Сәлем, менің атым [name], мен [age] жастамын."` хабарламасын шығаратын `introduce` әдісін қосыңыз.
# 4.  `Person` класының данасын (экземпляр) жасап, жұмысын тексеру үшін `introduce` әдісін шақырыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 2-тапсырма: Инкапсуляция (2 балл)
#
# 1.  `Person` класын `__password` жеке атрибутын қосу арқылы өзгертіңіз.
# 2.  Құпия сөзді орнататын `set_password(password)` әдісін құрыңыз.
# 3.  Берілген құпия сөз орнатылғанмен сәйкес келсе `True`, ал басқа жағдайда `False` қайтаратын `check_password(password)` әдісін құрыңыз.
# 4.  Инкапсуляцияның жұмысын тексеріңіз: объект құрып, құпия сөзді орнатыңыз және оны тексеріңіз.

# %%
# Сіздің шешіміңіз осында (алдыңғы тапсырманың кодын көшіріп, толықтыруға болады)

# %% [markdown]
# ### 3-тапсырма: Мұрагерлік (2 балл)
#
# 1.  `Person` класынан мұра алатын жаңа `Student` класын құрыңыз.
# 2.  `Student` конструкторында `super().__init__(...)` көмегімен ата-ана класының `Person` конструкторын шақырыңыз.
# 3.  `Student` класына жаңа `grade` (студенттің курсы) атрибутын қосыңыз.
# 4.  `"[name] [grade] курста оқиды."` деп шығаратын `study` әдісін қосыңыз.
# 5.  `Student` класының данасын жасап, оның қасиеттерін орнатыңыз және `introduce` (мұра етілген) және `study` әдістерін шақырыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 4-тапсырма: Полиморфизм (2 балл)
#
# 1.  `Person` класынан мұра алатын жаңа `Teacher` класын құрыңыз.
# 2.  `Teacher` класына `subject` (мұғалімнің пәні) атрибутын және `"[name] [subject] пәнін оқытады."` хабарламасын шығаратын `teach` әдісін қосыңыз.
# 3.  `Teacher` және `Student` класстарында `introduce` әдісін **қайта анықтаңыз**. Студент үшін ол қосымша курсын, ал мұғалім үшін пәнін хабарлауы керек.
# 4.  `Person`, `Student` және `Teacher` класстарының бір-бір объектісін қамтитын тізім құрыңыз.
# 5.  Тізімді аралап, әрбір объект үшін `introduce` әдісін шақыратын цикл жазыңыз. Әрбір класстың өзіне тән, бірегей хабарлама шығаратынына көз жеткізіңіз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 5-тапсырма: Абстрактілі класс (2 балл)
#
# 1.  `abc` модулінен `ABC` және `abstractmethod` импорттаңыз.
# 2.  `work()` абстрактілі әдісі бар `Worker` абстрактілі класын құрыңыз.
# 3.  `Student` және `Teacher` класстары `Worker`-ден мұра алатындай етіп жасаңыз.
# 4.  Екі класста да `work` әдісін іске асырыңыз. Студент үшін ол `"[name] зертханалық жұмысты орындайды."` деп, ал мұғалім үшін `"[name] жұмыстарды тексереді."` деп шығаруы керек.
# 5.  Жұмысты тексеріңіз: `Student` және `Teacher` объектілерін құрып, олардың `work` әдісін шақырыңыз.

# %%
# Сіздің шешіміңіз осында
