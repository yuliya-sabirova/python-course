# %% [markdown]
# # Лабораторная работа №2: Условные операторы, модули и введение в циклы и списки
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб2.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ## Часть 1. Простые условия (3 балла)
#
# В этой части вы должны продемонстрировать умение работать с конструкциями `if-else` и базовыми операторами сравнения. Каждое задание по 0.5 баллов

# %% [markdown]
# #### Задача 1: Проверка четности числа
#  Написать программу, которая запрашивает у пользователя целое число и определяет, является ли оно четным или нечетным.
# *Подсказка: используйте оператор остатка от деления `%`.*

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 2: Сравнение двух строк
# Написать программу, которая запрашивает у пользователя две строки и сообщает, равны ли они, игнорируя регистр.
# *Подсказка: приведите обе строки к одному регистру (например, нижнему) перед сравнением.*

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 3: Категория веса
# Написать программу, которая запрашивает у пользователя его вес в килограммах и сообщает, находится ли он в пределах "нормы" (60-90 кг включительно).

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 4: Проверка диапазона
# Написать программу, которая запрашивает у пользователя число и определяет, входит ли оно в диапазон от 0 до 100 (включительно).

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 5: Тернарный оператор 1
# Запросить у пользователя число. Присвоить переменной `result` строку `'even'` если число четное, и `'odd'` в противном случае. Вывести `result`. Задачу выполнить с применением тернарного оператора.

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 6: Тернарный оператор 2
#  Запросить у пользователя два числа. Присвоить переменной `result` большее из двух чисел. Вывести `result`. Задачу выполнить с применением тернарного оператора

# %%
# Ваше решение здесь

# %% [markdown]
# ## Часть 2. Сложные условия и модули (4 балла)
#
# В этой части необходимо использовать конструкции `if-elif-else`, логические операторы и, возможно, функции из модуля `math`. **Каждое задание по 1 баллу**

# %% [markdown]
# #### Задача 1: Калькулятор оценок
# Написать программу, которая принимает оценку по 100-балльной шкале и выводит оценку в буквенном формате согласно правилам:
# - 90-100: "Отлично"
# - 75-89: "Хорошо"
# - 50-74: "Удовлетворительно"
# - 0-49: "Неудовлетворительно"

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 2: Определение типа года (високосный или нет)
# Написать программу, которая запрашивает у пользователя год и определяет, является ли он високосным.
# **Правило:** Год является високосным, если он делится на 4, но не делится на 100, ИЛИ если он делится на 400.

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 3: Определение квадранта координатной плоскости
# Написать программу, которая запрашивает у пользователя координаты точки (x, y) и определяет, в каком квадранте она находится. Также обработайте случаи, когда точка лежит на одной из осей или в начале координат.

# %%
# Ваше решение здесь

# %% [markdown]
# #### Задача 4: Решение квадратного уравнения
# Написать программу для решения квадратного уравнения $ax^2 + bx + c = 0$.
# 1. Запросите у пользователя коэффициенты `a`, `b`, `c`.
# 2. Вычислите дискриминант $D = b^2 - 4ac$.
# 3. В зависимости от значения дискриминанта, выведите результат:
#    - Если $D > 0$: два различных корня.
#    - Если $D = 0$: один корень.
#    - Если $D < 0$: корней нет.
# *Подсказка: для вычисления корней вам понадобится `math.sqrt()`.*

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3. Попадание точки в область (2 балла)
#
# Напишите программу, которая запрашивает у пользователя координаты точки `(x, y)` и выводит сообщение, лежит ли точка в заштрихованной области.
#
# Каждый студент выполняет **два варианта**:
# 1.  Первый вариант по порядковому номеру в журнале (`N`).
# 2.  Второй вариант по формуле `23 - N`.
#
# Каждый вариант оценивается по 1 баллу.
#
# Варианты заданий (по ссылке открываем картинку): <br>
# [Варианты 1-6](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE1.png) <br>
# [Варианты 7-10](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE2.png) <br>
# [Варианты 11-14](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE3.png) <br>
# [Варианты 15-18](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE4.png) <br>
# [Варианты 19-22](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE5.png)

# %%
# Первый вариант, указать вариант

# %%
# Второй вариант, указать вариант

# %% [markdown]
# ### Задание 4. Обработка списка в цикле (1 балл)
#
# **Задача:** Дан список чисел. Напишите программу, которая делает перебор в цикле for элементов списка source_list, и выводит квадратный корень модуля **четных чисел** и пятую степень **нечетных чисел**.
#
# *Подсказка:* необходимо в цикле for проверить условием четность чисел. Для четных использовать .abs, .sqrt, для нечетных возвести в степень

# %%
import random
import math

# Этот код генерирует случайный список. Вам нужно его обработать.
source_list = random.sample(range(-100, 100), 15)
print(f"Исходный список: {source_list}")

# Ваше решение здесь
# Out:
# Исходный список: [-27, -75, 28, -5, -69, 25, 96, -44, 57, 86, -74, 2, -28, -92, -51]
