# %% [markdown]
# # Лабораторная работа №8: Практика ООП: Проектирование классов
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб8.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Цель работы:** Закрепить фундаментальные знания ООП, полученные на предыдущем занятии. Перейти от изучения синтаксиса к самостоятельному проектированию классов для решения практических задач. Научиться моделировать сущности с более сложным поведением.

# %% [markdown]
# ## Часть 1. Класс `Student` (4 балла)
#
# **Задача:** Реализовать класс `Student`, который описывает студента. Это задание выполняют **все студенты**.

# %% [markdown]
# ### Требования к классу `Student`:
#
# 1.  **Атрибуты:**
#     *   `id` (ID студента)
#     *   `surname` (фамилия)
#     *   `name` (имя)
#     *   `record_book_number` (номер зачетной книжки)
#     *   `gpa` (средний балл)
#     *   `python_score` (балл по Python)
#
# 2.  **Методы:**
#     *   **Конструктор `__init__`:** Принимает все перечисленные выше атрибуты при создании объекта.
#     *   **Геттеры и Сеттеры:** Для каждого атрибута должны быть созданы геттер (для получения значения) и сеттер (для установки значения). Например, `get_name()`, `set_name(new_name)`.
#     *   `print_fullname()`: Выводит на экран полное имя студента (имя и фамилия).
#     *   `print_id()`: Выводит ID студента.
#     *   `print_gpa()`: Выводит средний балл студента.
#     *   **Деструктор `__del__`:** Должен выводить сообщение `"Студент [Фамилия Имя] отчислен."`
#     *   **(Рекомендуется)** `__str__`: Реализуйте этот метод для удобного вывода информации об объекте `Student` (например, `print(student_object)`).
#
# 3.  **Программа для демонстрации:**
#     *   Создайте **один** экземпляр класса `Student` и продемонстрируйте работу всех его методов (геттеров, сеттеров и т.д.).
#     *   Создайте **список**, содержащий 3-4 экземпляра класса `Student`.
#     *   Напишите цикл, который проходит по этому списку и для каждого студента выводит его полное имя и балл по Python.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Часть 2. Класс "Геометрическая фигура" (6 баллов)
#
# **Задача:** Реализовать один из трех классов для описания геометрической фигуры согласно вашему варианту.
#
# **Определение варианта:** Ваш вариант определяется по формуле `(N - 1) % 3 + 1`, где `N` — ваш номер в списке группы.
# -   **Вариант 1:** Класс `Triangle`
# -   **Вариант 2:** Класс `Rectangle`
# -   **Вариант 3:** Класс `Circle`

# %% [markdown]
# ### Требования к классам:
#
# #### Вариант 1: `Triangle`
# -   **Атрибуты:** `side_a`, `side_b`, `side_c` (стороны треугольника).
# -   **Методы:**
#     -   Конструктор `__init__`.
#     -   Геттеры и сеттеры для каждой стороны. Поиграйте с уровнем доступа к атрибутам класса.
#     -   `area()`: вычисляет и возвращает площадь треугольника (можно использовать формулу Герона).
#     -   `perimeter()`: вычисляет и возвращает периметр.
#     -   `check_type()`: проверяет и выводит, является ли треугольник равнобедренным, равносторонним или разносторонним.
# -   **Программа для демонстрации:** Создайте объект класса, вызовите все методы и выведите результаты на экран.
#
# #### Вариант 2: `Rectangle`
# -   **Атрибуты:** `side_a`, `side_b` (стороны прямоугольника).
# -   **Методы:**
#     -   Конструктор `__init__`.
#     -   Геттеры и сеттеры для каждой стороны. Поиграйте с уровнем доступа к атрибутам класса.
#     -   `area()`: вычисляет и возвращает площадь.
#     -   `perimeter()`: вычисляет и возвращает периметр.
#     -   `is_square()`: возвращает `True`, если прямоугольник является квадратом, и `False` в противном случае.
# -   **Программа для демонстрации:** Создайте объект класса, вызовите все методы и выведите результаты на экран.
#
# #### Вариант 3: `Circle`
# -   **Атрибуты:** `radius` (радиус круга).
# -   **Методы:**
#     -   Конструктор `__init__`.
#     -   Геттер и сеттер для радиуса. Поиграйте с уровнем доступа к атрибутам класса
#     -   `area()`: вычисляет и возвращает площадь круга.
#     -   `circumference()`: вычисляет и возвращает длину окружности.
#     -   `is_integer_radius()`: возвращает `True`, если радиус является целым числом, и `False` в противном случае.
# -   **Программа для демонстрации:** Создайте объект класса, вызовите все методы и выведите результаты на экран.

# %%
# Ваше решение здесь
