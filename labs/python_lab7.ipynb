# %% [markdown]
# # Лабораторная работа №7: Основы ООП в Python
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб7.ipynb`
#
# **Общая оценка:** 10 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Цель работы:** Познакомиться с новой парадигмой программирования — ООП. Научиться мыслить в терминах объектов, которые объединяют в себе и данные, и поведение. Создать свои первые классы и пошагово реализовать в них ключевые принципы ООП: инкапсуляцию, наследование и полиморфизм.

# %% [markdown]
# ### Теоретическая часть:
#
# Перед началом работы убедитесь, что вы понимаете следующие термины:
# -   **Класс и объект**
# -   **Атрибуты и методы**
# -   **Инкапсуляция**
# -   **Наследование**
# -   **Полиморфизм**
# -   **Абстрактный класс**

# %% [markdown]
# ## Задания
# Эта работа представляет собой единый пошаговый проект, где каждое следующее задание дорабатывает предыдущее. Каждое задание оценивается в 2 балла.

# %% [markdown]
# ### Задание 1: Создание базового класса (2 балла)
#
# 1.  Создайте класс `Person`, который будет представлять человека.
# 2.  В конструкторе `__init__` определите два атрибута: `name` (имя) и `age` (возраст).
# 3.  Добавьте метод `introduce`, который выводит сообщение: `"Привет, меня зовут [name], и мне [age] лет."`
# 4.  Создайте экземпляр класса `Person` и вызовите метод `introduce`, чтобы проверить работу.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 2: Инкапсуляция (2 балла)
#
# 1.  Модифицируйте класс `Person`, добавив приватный атрибут `__password`.
# 2.  Создайте метод `set_password(password)`, который устанавливает пароль.
# 3.  Создайте метод `check_password(password)`, который возвращает `True`, если переданный пароль совпадает с установленным, и `False` в противном случае.
# 4.  Протестируйте работу инкапсуляции: создайте объект, установите пароль и проверьте его.

# %%
# Ваше решение здесь (можно скопировать код из предыдущего задания и доработать)

# %% [markdown]
# ### Задание 3: Наследование (2 балла)
#
# 1.  Создайте новый класс `Student`, который наследуется от класса `Person`.
# 2.  В конструкторе `Student` вызовите конструктор родительского класса `Person` с помощью `super().__init__(...)`.
# 3.  Добавьте к классу `Student` новый атрибут `grade` (курс студента).
# 4.  Добавьте метод `study`, который выводит: `"[name] учится на [grade] курсе."`
# 5.  Создайте экземпляр класса `Student`, задайте его свойства и вызовите методы `introduce` (унаследованный) и `study`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 4: Полиморфизм (2 балла)
#
# 1.  Создайте новый класс `Teacher`, который также наследуется от класса `Person`.
# 2.  Добавьте `Teacher` атрибут `subject` (предмет преподавателя) и метод `teach`, который выводит сообщение: `"[name] преподает [subject]."`
# 3.  **Переопределите** в `Teacher` и `Student` метод `introduce`. Для студента он должен дополнительно сообщать курс, а для учителя — предмет.
# 4.  Создайте список, содержащий по одному объекту классов `Person`, `Student` и `Teacher`.
# 5.  Напишите цикл, который проходит по списку и вызывает для каждого объекта метод `introduce`. Убедитесь, что у каждого класса выводится свое, уникальное сообщение.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 5: Абстрактный класс (2 балла)
#
# 1.  Импортируйте `ABC` и `abstractmethod` из модуля `abc`.
# 2.  Создайте абстрактный класс `Worker` с абстрактным методом `work()`.
# 3.  Сделайте так, чтобы классы `Student` и `Teacher` наследовались от `Worker`.
# 4.  Реализуйте метод `work` в обоих классах. Для студента он должен выводить `"[name] выполняет лабораторную работу."`, а для учителя — `"[name] проверяет работы."`.
# 5.  Протестируйте работу: создайте объекты `Student` и `Teacher` и вызовите их метод `work`.

# %%
# Ваше решение здесь
