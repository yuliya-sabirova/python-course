# %% [markdown]
# # Лабораторная работа №5: Функции — практика
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб5.ipynb`
#
# **Общая оценка:** 20 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Цель работы:** Научиться декомпозировать (разделять) сложные задачи на более простые подзадачи, оформляя их в виде функций. Освоить синтаксис определения функций (`def`), передачи аргументов и возврата значений (`return`). Понять разницу между функциями, которые возвращают результат, и процедурами, которые просто выполняют действия.

# %% [markdown]
# ### Порядок выполнения
#
# В этой работе вам предстоит решить 10 задач. Каждая задача оценивается разным количеством баллов в зависимости от ее сложности и концепций, которые она затрагивает.
#
# **Распределение баллов:**
# - Задание 1: 1.5 балла
# - Задание 2: 1.5 балла
# - Задание 3: 2.5 балла
# - Задание 4: 1.5 балла
# - Задание 5: 2.5 балла
# - Задание 6: 2.0 балла
# - Задание 7: 2.0 балла
# - Задание 8: 2.5 балла
# - Задание 9: 2.5 балла
# - Задание 10: 1.5 балла
#
# **Итого: 20 баллов**

# %% [markdown]
# ### Задание 1. Произведение двух наибольших (1.5 балла)
#
# **Задача:** Написать функцию, которая принимает три введенных пользователем числа и возвращает произведение двух наибольших.
#
# **Требуется знать:** `if/elif/else`, `min()`, `max()`, создание функции, `return`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 2. Генератор случайного списка (1.5 балла)
#
# **Задача:** Написать функцию, возвращающую список заданной размерности, заполненный случайными числами.
#
# **Требуется знать:** `import random`, `random.randint()`, циклы, создание функции, передача параметров.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3. Проверка вхождения в список (2.5 балла)
#
# **Задача:** Написать программу, в которой пользователь добавляет элементы в список, пока не введет 'stop'. После этого пользователь вводит число для проверки, а программа с помощью отдельной функции проверяет, входит ли это число в список, и выводит `True` или `False`.
#
# **Требуется знать:** `while`, методы списка, оператор `in`, создание функции.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 4. Факториал (1.5 балла)
#
# **Задача:** Написать функцию для вычисления факториала числа. Использовать встроенную функцию `math.factorial` **запрещено**.
#
# **Требуется знать:** Создание функции, циклы, формула факториала ($n! = 1 \cdot 2 \cdot ... \cdot n$, $0! = 1$).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 5. Числа Фибоначчи (без `return`) (2.5 балла)
#
# **Цель:** Понять отличие между функцией, возвращающей значение (`return`), и процедурой, которая просто выполняет действия (например, `print`).
#
# **Задача:** Написать функцию, которая **печатает** последовательность чисел Фибоначчи до заданного `N`, а также выводит их количество и сумму. Использовать `return` в этой функции **запрещено**.
#
# **Пример отличия:**
# ```python
# # Процедура (просто печатает)
# def proc(n):
#     print(n)
# proc(5) # На экране: 5
#
# # Функция (возвращает значение)
# def func(n):
#     return n
# result = func(5) # В result теперь лежит 5
# print(result)    # На экране: 5
# ```
#
# **Требуется знать:** Последовательность Фибоначчи, условные операторы, циклы, отличие `print` от `return`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 6. Форматирование строки (2.0 балла)
#
# **Задача:** Написать функцию, которая принимает на вход строку, разделитель и окончание. Функция должна разбить строку по разделителю и вывести части строки, добавив к каждой указанное окончание.
#
# **Пример вывода:**
# ```
# # Вызов: my_func('Какой прекрасный действенный элексир', 'й', '+\n')
# Како+
# Прекрасны+
# де+
# ственны+
# элексир+
# ```
#
# **Требуется знать:** Методы строк, функция без `return`, `print()` с параметрами `sep` и `end`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 7. Обновление словаря (2.0 балла)
#
# **Задача:** Написать функцию, принимающую словарь и список. Функция должна вернуть новый словарь, в котором значения из исходного словаря заменены на значения из списка. Предполагается, что количество элементов совпадает.
#
# **Пример:**
# ```python
# d = {1:2, 3:4}
# l =
# # Результат: {1:5, 3:6}
# ```
#
# **Требуется знать:** Работа со словарями, списками, циклами.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 8. Сумма элементов кортежа (2.5 балла)
#
# **Цель:** Научиться использовать **аргументы по умолчанию** в функциях.
#
# **Задача:** Написать функцию, в которую передается кортеж с числами. Функция возвращает сумму элементов, которые больше нуля и делятся на 7 без остатка. Если кортеж не передан, функция должна использовать кортеж натуральных чисел от 1 до 10.
#
# **Требуется знать:** Условный оператор (`if`, `and`), циклы, **аргументы по умолчанию**.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 9. Произведение элементов кортежа (2.5 балла)
#
# **Цель:** Закрепить использование **аргументов по умолчанию**.
#
# **Задача:** Написать функцию, в которую передается кортеж с числами. Функция возвращает произведение элементов, которые меньше нуля или делятся на 3 без остатка. Если кортеж не передан, функция должна использовать кортеж натуральных чисел от 1 до 10.
#
# **Требуется знать:** Условный оператор (`if`, `or`), циклы, **аргументы по умолчанию**.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 10. Смешивание цветов (1.5 балла)
#
# **Задача:** Написать функцию, принимающую два основных цвета ("красный", "синий", "желтый"). Функция должна возвращать вторичный цвет, который получится в результате смешивания, или сообщение об ошибке, если введены некорректные цвета.
#
# **Правила смешивания:**
# - красный + синий = фиолетовый
# - красный + желтый = оранжевый
# - синий + желтый = зеленый
# - Если смешать одинаковые цвета, получится тот же цвет.
#
# **Требуется знать:** Условный оператор (`if/elif/else`), передача аргументов в функцию.

# %%
# Ваше решение здесь
