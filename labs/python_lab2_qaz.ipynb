# %% [markdown]
# # №2 Зертханалық жұмыс: Шартты операторлар, модульдер және циклдер мен тізімдерге кіріспе
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АТЫ-ЖӨНІ_мамандық_зерт2.ipynb` форматында болуы керек
#
# **Жалпы баға:** 10 балл

# %% [markdown]
# ## 1-бөлім. Қарапайым шарттар (3 балл)
#
# Бұл бөлімде сіз `if-else` конструкцияларымен және негізгі салыстыру операторларымен жұмыс істеу қабілетіңізді көрсетуіңіз керек. Әр тапсырма 0.5 баллмен бағаланады.

# %% [markdown]
# #### 1-тапсырма: Санның жұптығын тексеру
#  Қолданушыдан бүтін санды сұрайтын және оның жұп немесе тақ екенін анықтайтын бағдарлама жазыңыз.
# *Кеңес: `%` бөлуден қалдықты табу операторын қолданыңыз.*

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 2-тапсырма: Екі жолды салыстыру
# Қолданушыдан екі жолды сұрайтын және олардың регистрді ескермей тең екендігін хабарлайтын бағдарлама жазыңыз.
# *Кеңес: Салыстырмас бұрын екі жолды да бір регистрге (мысалы, төменгі) келтіріңіз.*

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 3-тапсырма: Салмақ категориясы
# Қолданушыдан оның салмағын килограммен сұрайтын және оның "қалыпты" (60-90 кг қоса алғанда) шегінде екендігін хабарлайтын бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 4-тапсырма: Диапазонды тексеру
# Қолданушыдан санды сұрайтын және оның 0-ден 100-ге дейінгі (қоса алғанда) диапазонға кіретінін анықтайтын бағдарлама жазыңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 5-тапсырма: Тернарлық оператор 1
# Қолданушыдан сан сұраңыз. Егер сан жұп болса, `result` айнымалысына `'even'` жолын, ал тақ болса `'odd'` жолын тағайындаңыз. `result` мәнін шығарыңыз. Тапсырманы тернарлық операторды қолданып орындаңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 6-тапсырма: Тернарлық оператор 2
#  Қолданушыдан екі сан сұраңыз. `result` айнымалысына екі санның үлкенін тағайындаңыз. `result` мәнін шығарыңыз. Тапсырманы тернарлық операторды қолданып орындаңыз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ## 2-бөлім. Күрделі шарттар және модульдер (4 балл)
#
# Бұл бөлімде `if-elif-else` конструкцияларын, логикалық операторларды және `math` модулінің функцияларын қолдану қажет. **Әр тапсырма 1 баллмен бағаланады.**

# %% [markdown]
# #### 1-тапсырма: Бағалар калькуляторы
# 100-баллдық шкала бойынша бағаны қабылдайтын және келесі ережелерге сәйкес әріптік форматта баға шығаратын бағдарлама жазыңыз:
# - 90-100: "Өте жақсы"
# - 75-89: "Жақсы"
# - 50-74: "Қанағаттанарлық"
# - 0-49: "Қанағаттанарлықсыз"

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 2-тапсырма: Жыл түрін анықтау (кібісе немесе кәдімгі)
# Қолданушыдан жылды сұрайтын және оның кібісе жыл екенін анықтайтын бағдарлама жазыңыз.
# **Ереже:** Жыл 4-ке бөлінсе, бірақ 100-ге бөлінбесе, НЕМЕСЕ 400-ге бөлінсе, ол кібісе болып табылады.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 3-тапсырма: Координаталық жазықтықтың квадрантын анықтау
# Қолданушыдан нүктенің координаталарын (x, y) сұрайтын және оның қай квадрантта орналасқанын анықтайтын бағдарлама жазыңыз. Нүкте осьтердің бірінде немесе координаталар басында орналасқан жағдайларды да өңдеңіз.

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# #### 4-тапсырма: Квадрат теңдеуді шешу
# $ax^2 + bx + c = 0$ квадрат теңдеуін шешуге арналған бағдарлама жазыңыз.
# 1. Қолданушыдан `a`, `b`, `c` коэффициенттерін сұраңыз.
# 2. Дискриминантты есептеңіз: $D = b^2 - 4ac$.
# 3. Дискриминанттың мәніне байланысты нәтижені шығарыңыз:
#    - Егер $D > 0$: екі әртүрлі түбір бар.
#    - Егер $D = 0$: бір түбір бар.
#    - Егер $D < 0$: түбірлері жоқ.
# *Кеңес: түбірлерді есептеу үшін сізге `math.sqrt()` қажет болады.*

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3-тапсырма. Нүктенің аймаққа тиесілігін тексеру (2 балл)
#
# Қолданушыдан `(x, y)` нүктесінің координаталарын сұрайтын және нүктенің штрихталған аймақта жатқаны туралы хабарлама шығаратын бағдарлама жазыңыз.
#
# Әрбір студент **екі нұсқаны** орындайды:
# 1.  Журналдағы реттік нөмірі (`N`) бойынша бірінші нұсқаны.
# 2.  `23 - N` формуласы бойынша екінші нұсқаны.
#
# Әр нұсқа 1 баллмен бағаланады.
#
# Тапсырма нұсқалары (суретті ашу үшін сілтемені басыңыз): <br>
# [1-6 нұсқалар](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE1.png) <br>
# [7-10 нұсқалар](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE2.png) <br>
# [11-14 нұсқалар](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE3.png) <br>
# [15-18 нұсқалар](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE4.png) <br>
# [19-22 нұсқалар](https://github.com/yuliya-sabirova/python-course/blob/main/labs/img/IFELSE5.png)

# %%
# Бірінші нұсқа, нұсқаны көрсетіңіз

# %%
# Екінші нұсқа, нұсқаны көрсетіңіз

# %% [markdown]
# ### 4-тапсырма. Тізімді циклде өңдеу (1 балл)
#
# **Есеп:** Сандар тізімі берілген. `source_list` тізімінің элементтерін `for` циклі арқылы іріктеп, **жұп сандардың** модулінен квадрат түбірді және **тақ сандардың** бесінші дәрежесін шығаратын бағдарлама жазыңыз.
#
# *Кеңес:* `for` циклі ішінде шартпен сандардың жұптығын тексеру керек. Жұп сандар үшін `.abs`, `.sqrt` қолданыңыз, ал тақ сандарды дәрежеге шығарыңыз.

# %%
import random
import math

# Бұл код кездейсоқ тізімді генерациялайды. Сізге оны өңдеу керек.
source_list = random.sample(range(-100, 100), 15)
print(f"Бастапқы тізім: {source_list}")

# Сіздің шешіміңіз осында
