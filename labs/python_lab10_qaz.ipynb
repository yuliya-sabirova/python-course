# %% [markdown]
# # №10 Зертханалық жұмыс: Pandas негіздері
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АТ_мамандық_зерт10.ipynb` форматында болуы керек
#
# **Жалпы баға:** 10 балл

# %% [markdown]
# ### Жұмыстың мақсаты
# Аналитикада ең көп таралған деректер форматы — кестелік деректермен жұмыс істеуді үйрену. Pandas кітапханасының көмегімен деректерді жүктеуді, қарап шығуды, негізгі сүзуді және сұрыптауды меңгеру.

# %% [markdown]
# ## 1-бөлім: `mpg.csv` деректер жинағымен жаттығу (3 балл)
#
# Бұл бөлімде сіз автомобильдердің сипаттамалары бар деректер жинағында негізгі дағдыларды пысықтайсыз.

# %% [markdown]
# ### 1.1-тапсырма: Жүктеу және бастапқы қарап шығу (1 балл)
#
# 1.  Pandas кітапханасын `pd` деп импорттаңыз.
# 2.  `mpg.csv` деректер жинағын `df` атты DataFrame-ге жүктеңіз.
#     > **Маңызды:** `horsepower` бағанында `'?'` түріндегі қате мәндер бар. Pandas оларды бос орындар ретінде дұрыс тануы үшін `pd.read_csv()` функциясында `na_values='?'` параметрін қолданыңыз.
# 3.  Алғашқы 5 жолды шығарыңыз.
# 4.  DataFrame-нің өлшемін шығарыңыз.
# 5.  DataFrame туралы жалпы ақпаратты шығарыңыз, деректер типтеріне және `horsepower` бағанындағы бос орындардың болуына назар аударыңыз.

# %%
# Сіздің кодыңыз осында

# %% [markdown]
# ### 1.2-тапсырма: Сүзу және бағандар құру (2 балл)
#
# 1.  Автомобильдің салмағын килограммен көрсететін `weight_kg` атты жаңа баған құрыңыз. Келесі формуланы қолданыңыз: 1 фунт = 0.453592 кг. Нәтижені үтірден кейін 2 таңбаға дейін дөңгелектеңіз.
# 2.  БАРЛЫҚ үш шартқа сәйкес келетін автомобильдерден тұратын `american_powerful_cars` DataFrame-ін құрыңыз:
#     *   `origin` 1-ге тең (Америкалық)
#     *   `cylinders` 8-ге тең
#     *   `horsepower` 150-ден көп
# 3.  `american_powerful_cars` DataFrame-ін `horsepower` бойынша кему ретімен сұрыптап, алғашқы 5 жолды шығарыңыз.

# %%
# Сіздің кодыңыз осында

# %% [markdown]
# ## 2-бөлім: `hotel_booking_data.csv` деректер жинағымен негізгі тапсырма (7 балл)

# %% [markdown]
# ### 2.1-тапсырма: Жүктеу және бастапқы қарап шығу (1 балл)
#
# 1. `hotel_booking_data.csv` файлын `hotels` атты DataFrame-ге жүктеңіз.
# 2. DataFrame-нің алғашқы 7 жолын шығарыңыз.
# 3. `.info()` әдісін пайдаланып, DataFrame туралы жалпы ақпаратты шығарыңыз. Деректерде бос орындар бар ма?

# %%
# Сіздің кодыңыз осында

# %% [markdown]
# ### 2.2-тапсырма: Бағандармен жұмыс (1.5 балл)
#
# 1. `stays_in_weekend_nights` және `stays_in_week_nights` бағандарының қосындысы болатын `total_nights` атты жаңа баған құрыңыз.
# 2. `adults`, `children` және `babies` бағандарының қосындысы болатын `total_guests` бағанын құрыңыз.
# 3. `hotels` DataFrame-інен `name`, `email`, `phone-number` және `credit_card` бағандарын жойыңыз.
# 4. Жаңартылған DataFrame-нің `.head()`-ын шығарыңыз.

# %%
# Сіздің кодыңыз осында

# %% [markdown]
# ### 2.3-тапсырма: Деректерді сүзу (2.0 балл)
#
# 1. Қанша брондаудан бас тартылды (`is_canceled` == 1)?
# 2. Тек `Resort Hotel`-ге арналған брондаулардан тұратын `resort_bookings` DataFrame-ін құрыңыз.
# 3. `total_nights` 10-нан асатын брондаулардан тұратын `long_stay_bookings` DataFrame-ін құрыңыз.
# 4. `City Hotel`-ге арналған, `total_guests` > 3 және `total_of_special_requests` > 0 шарттарына сәйкес келетін брондаулардан тұратын `vip_bookings` DataFrame-ін құрыңыз. Осындай брондаулардың саны қанша?

# %%
# Сіздің кодыңыз осында

# %% [markdown]
# ### 2.4-тапсырма: Санаттарды талдау және сұрыптау (2.5 балл)
#
# 1. Барлық брондаулар арасында қай ел (`country`) ең жиі кездеседі?
# 2. Нарықтың әрбір сегментінде (`market_segment`) қанша брондау жасалды? (`.value_counts()` қолданыңыз)
# 3. Ең қымбат 5 брондауды табыңыз (`adr` бойынша - бөлме үшін орташа баға).
# 4. **(Кешенді есеп)** `Resort Hotel`-дегі **екіден астам** арнайы сұранысы бар (`total_of_special_requests > 2`) **бас тартылмаған** барлық брондаулар үшін **бір қонаққа шаққандағы бір түннің орташа бағасын** (`adr` / `total_guests`) табыңыз.

# %%
# Сіздің кодыңыз осында
