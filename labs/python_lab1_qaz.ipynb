# %% [markdown]
# # №1 Зертханалық жұмыс: Негіздер және мәтінмен жұмыс
#
# **Аты-жөні:** _________________________
#
# **Ескерту:** Файл атауы `АЖ_MM-23-9_lab1.ipynb` пішімінде болуы керек
#
# **Жалпы баға:** 10 балл

# %% [markdown]
# ## 1-бөлім. Негізгі операциялар (4 балл)
#
# Бұл бөлімде сіз айнымалылармен, енгізу-шығарумен және негізгі арифметикалық операциялармен жұмыс істей білуіңізді көрсетуіңіз керек.

# %% [markdown]
# ### 1-тапсырма. Сәлемдесу және жасты есептеу (1 балл)
#
# **Мақсаты:** Келесідей бағдарлама жазу:
# 1. Пайдаланушыдан оның атын сұрайды.
# 2. Пайдаланушыдан оның туған жылын сұрайды.
# 3. Пайдаланушының атымен сәлемдесу хабарын шығарады.
# 4. Пайдаланушының шамамен жасын есептеп, экранға шығарады.
#
# **Енгізу мысалы:**
# ```
# Атыңызды енгізіңіз: Әлиса
# Туған жылыңызды енгізіңіз: 2003
# ```
#
# **Шығару мысалы:**
# ```
# Сәлем, Әлиса!
# Биыл сіз шамамен 21 жасқа толасыз.
# ```

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 2-тапсырма. Қарапайым аудан калькуляторы (1.5 балл)
#
# **Мақсаты:** Тіктөртбұрыштың ауданы мен периметрін есептейтін бағдарлама жазу.
# 1. Пайдаланушыдан тіктөртбұрыштың ұзындығы мен енін сұраңыз (бөлшек сандар болуы мүмкін).
# 2. Ауданды келесі формула бойынша есептеңіз: `Аудан = Ұзындық * Ені`.
# 3. Периметрді келесі формула бойынша есептеңіз: `Периметр = 2 * (Ұзындық + Ені)`.
# 4. Нәтижелерді түсіндірме жазулармен экранға шығарыңыз.
#
# **Енгізу мысалы:**
# ```
# Тіктөртбұрыштың ұзындығын енгізіңіз: 5.5
# Тіктөртбұрыштың енін енгізіңіз: 3.2
# ```
#
# **Шығару мысалы:**
# ```
# Тіктөртбұрыштың ауданы: 17.6
# Тіктөртбұрыштың периметрі: 17.4
# ```

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 3-тапсырма. Бүтін санды арифметика (1.5 балл)
#
# **Мақсаты:** Бүтін санды бөлу және қалдықпен жұмыс істейтін бағдарлама жазу.
# 1. Сізде `K` студентке тарату керек `N` алма бар деп елестетіңіз.
# 2. Пайдаланушыдан алмалар мен студенттер санын сұраңыз (бүтін сандар).
# 3. Әр студентке қанша алмадан тиетінін есептеңіз.
# 4. Себетте қанша алма қалатынын есептеңіз.
# 5. Нәтижелерді экранға шығарыңыз.
#
# **Енгізу мысалы:**
# ```
# Себетте қанша алма бар? 50
# Топта қанша студент бар? 7
# ```
#
# **Шығару мысалы:**
# ```
# Әр студент 7 алмадан алады.
# Себетте 1 алма қалады.
# ```

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ## 2-бөлім. Жолдармен жұмыс (6 балл)
#
# Бұл бөлімде сіздің мәтіндік деректерді өңдеу дағдыларыңыз тексеріледі.

# %% [markdown]
# ### 4-тапсырма. Аккаунт генераторы (2 балл)
# **Мақсаты:** Пайдаланушының бірегей идентификаторын жасайтын бағдарлама жазу.
# 1. Пайдаланушыдан **Атын**, **Тегін** және **туған жылын** сұрау.
# 2. Келесі бөлшектерден тұратын идентификатор құру:
#    - Есімнің алғашқы 3 әрпі.
#    - Тегінің алғашқы 3 әрпі.
#    - Туған жылдың соңғы 2 саны.
# 3. Барлық идентификатор төменгі регистрде болуы керек.
# 4. Нәтижені шығару.
#
# **Енгізу мысалы:**
# ```
# Сіздің атыңыз: Қайрат
# Сіздің тегіңіз: Айбеков
# Туған жылыңыз: 2005
# ```
#
# **Шығару мысалы:**
# ```
# Толық аты-жөні: Қайрат Айбеков
# Аккаунт: қайайб05
# ```

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 5-тапсырма. Логин құру (2 балл)
#
# **Мақсаты:** Email-дан логин жасайтын бағдарлама жазу.
# 1. Пайдаланушыдан оның email-ын сұраңыз (мысалы, `user.name@example.com`).
# 2. Жолдың `@` символына дейінгі бөлігін алыңыз.
# 3. Алынған бөліктегі барлық нүктелерді `.` астыңғы сызықша `_` символына ауыстырыңыз.
# 4. Алынған логинді төменгі регистрде шығарыңыз.
#
# **Енгізу мысалы:**
# ```
# Email-ыңызды енгізіңіз: John.Doe@google.com
# ```
#
# **Шығару мысалы:**
# ```
# Сіздің логиніңіз: john_doe
# ```

# %%
# Сіздің шешіміңіз осында

# %% [markdown]
# ### 6-тапсырма. Сөзді кері айналдыру (Реверс) (2 балл)
#
# **Мақсаты:** Енгізілген сөзді кері айналдырып, оны талдайтын бағдарлама жазу.
# 1. Пайдаланушыдан бір сөз сұраңыз.
# 2. Бұл сөзді кесінді (срез) арқылы кері айналдырыңыз.
# 3. Кері айналдырылған сөзді шығарыңыз.
# 4. **Бастапқы** сөздің бірінші және соңғы символдарын шығарыңыз.
#
# **Енгізу мысалы:**
# ```
# Сөзді енгізіңіз: бағдарламалау
# ```
#
# **Шығару мысалы:**
# ```
# Керісінше сөз: уаламардалғаб
# Бірінші символ: б
# Соңғы символ: у
# ```

# %%
# Сіздің шешіміңіз осында
