# %% [markdown]
# # Лабораторная работа №6: Файлы, лямбда-функции и рекурсия
#
# **ФИО:** _________________________
#
# **Напоминание:** Название файла должно иметь формат `ФИ_специальность_лаб6.ipynb`
#
# **Общая оценка:** 20 баллов

# %% [markdown]
# ### Аннотация к работе
#
# **Ключевые темы:** Открытие файлов (`open()`), чтение и запись, контекстный менеджер `with`. Анонимные функции `lambda`. Рекурсивные функции.
#
# **Цель работы:** Научиться сохранять и читать данные из файлов, что позволяет сделать результаты работы программы постоянными. Освоить новые парадигмы программирования через лямбда-функции и рекурсию. Применить все ранее изученные навыки (циклы, функции, структуры данных) для обработки файловых данных.

# %% [markdown]
# ## Часть 1. Рекурсивные функции (4.5 балла)
#
# В этой части необходимо реализовать несколько классических алгоритмов с использованием рекурсии. Каждое задание оценивается в 1.5 балла.

# %% [markdown]
# ### Задание 1.1: Наибольший общий делитель (НОД)
#
# **Задача:** Описать рекурсивную функцию `NOD(A, B)` для нахождения наибольшего общего делителя двух целых положительных чисел, используя алгоритм Евклида:
# - `НОД(А, В) = НОД(В, А % В)`, если `В ≠ 0`
# - `НОД(А, 0) = A`
#
# С помощью этой функции найдите НОД для нескольких пар чисел (например, (32, 24), (1024, 64)).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 1.2: Рекурсивное возведение в степень
#
# **Задача:** Описать рекурсивную функцию `PowerN(X, N)` вещественного типа, находящую значение N-й степени числа X по формулам:
# - $X^0 = 1$;
# - $X^N = (X^{N/2})^2$ при четных N > 0;
# - $X^N = X \cdot X^{N-1}$ при нечетных N > 0.
#
# С помощью этой функции найдите степень для нескольких пар чисел (например, (2, 10), (3, 5)).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 1.3: Двойной факториал
#
# **Задача:** Описать рекурсивную функцию `Fact2(N)` для вычисления двойного факториала:
# $N!! = N \cdot (N-2) \cdot (N-4) \cdot ...$
#
# Последний сомножитель в произведении равен 2, если N — четное число, и 1, если N — нечетное. Базовыми случаями будут `Fact2(1)=1` и `Fact2(2)=2`.
#
# Вычислите двойные факториалы для чисел от 5 до 8.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Часть 2. Анонимные функции (Lambda) (4.5 балла)
#
# В этой части вам предстоит попрактиковаться в использовании `lambda` функций совместно с функциями высшего порядка. Каждое задание оценивается в 1.5 балла.

# %% [markdown]
# ### Задание 2.1: Квадраты чисел с `map`
#
# **Задача:** Дан список чисел. С помощью `lambda` и `map()` создайте новый список, содержащий квадраты чисел из исходного списка.

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]
# Ваше решение здесь

# %% [markdown]
# ### Задание 2.2: Фильтрация нечетных чисел с `filter`
#
# **Задача:** Дан список чисел. С помощью `lambda` и `filter()` отберите только нечетные числа.

# %%
numbers = [10, 23, 44, 51, 60, 75, 80, 99]
# Ваше решение здесь

# %% [markdown]
# ### Задание 2.3: Сортировка списка строк по длине
#
# **Задача:** Дан список строк. Отсортируйте этот список по возрастанию длины строк с помощью `lambda` функции.

# %%
words = ["python", "is", "a", "powerful", "language"]
# Ваше решение здесь

# %% [markdown]
# ## Часть 3. Работа с файлами (Синтез) (11 баллов)
#
# Этот блок объединяет все изученные темы. Вам предстоит читать данные из файлов, обрабатывать их и записывать результаты.
#
# **Подготовка:** Перед выполнением заданий создайте в той же папке, где находится ваш ноутбук, текстовый файл `data.txt` и скопируйте в него следующий текст:
# ```
# Это первая строка для лабораторной работы.
# Python - замечательный язык программирования.
#
# Работа с файлами является важной частью программирования.
# Умение читать и записывать данные - ключ к успеху.
# Успех приходит к тем, кто много практикуется.
# ```

# %% [markdown]
# ### Задание 3.1: Создание и запись в файл (1 балл)
#
# **Задача:** Напишите программу, которая создает текстовый файл `myfirstfile.txt` и записывает в него несколько строк текста, введенных пользователем. Затем откройте файл для чтения и выведите его содержимое на экран.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.2: Нумерация строк (1 балл)
#
# **Задача:** Напишите программу, которая открывает файл `data.txt` для чтения, нумерует каждую строку и записывает результат в новый файл `numbered_data.txt` в формате `"N: Исходная строка"`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.3: Копирование файла (1 балл)
#
# **Задача:** Напишите программу, которая создает полную копию файла `data.txt` с новым именем `data_copy.txt`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.4: Подсчет слов в файле (с вариантами) (1 балл)
#
# **Инструкция:** Ваш вариант определяется по формуле `(N - 1) % 4 + 1`, где `N` — ваш номер в списке группы. Реализуйте только ваш вариант.
#
# **Задача:** Напишите программу, которая подсчитывает общее количество и количество уникальных слов в файле `data.txt` согласно вашему варианту.
# -   **Вариант 1:** Простой подсчет. Слова разделяются пробелами. `"Слово"` и `"слово"` считаются разными словами. Знаки препинания являются частью слова.
# -   **Вариант 2:** Подсчет без учета регистра. `"Слово"` и `"слово"` считаются одним и тем же словом.
# -   **Вариант 3:** Без учета регистра и знаков препинания. `"программирования."` и `"программирования"` считаются одним словом. (Удалите точки, запятые, тире).
# -   **Вариант 4:** Продвинутый подсчет. Как в варианте 3, но слова должны состоять только из букв (цифры и прочие символы игнорируются).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.5: Поиск и замена в файле (с вариантами) (1 балл)
#
# **Инструкция:** Ваш вариант определяется по формуле `(N - 1) % 4 + 1`, где `N` — ваш номер в списке группы.
#
# **Задача:** Напишите программу, которая запрашивает у пользователя слово для поиска и слово для замены, а затем создает новый файл `replaced_data.txt` с замененными словами согласно варианту.
# -   **Вариант 1:** Простая замена подстроки с учетом регистра (используйте `str.replace()`).
# -   **Вариант 2:** Замена только целых слов с учетом регистра.
# -   **Вариант 3:** Замена подстроки без учета регистра.
# -   **Вариант 4:** Замена только целых слов без учета регистра.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.6: Объединение файлов (1 балл)
#
# **Задача:** Создайте еще два небольших текстовых файла (`add1.txt`, `add2.txt`). Напишите программу, которая объединяет содержимое `data.txt`, `add1.txt` и `add2.txt` в один итоговый файл `merged_data.txt`.

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.7: Удаление пустых строк (1 балл)
#
# **Задача:** Напишите программу, которая читает файл `data.txt` и создает его копию `no_empty_lines_data.txt`, в которой удалены все пустые строки (включая строки, состоящие только из пробелов).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.8: Анализ лог-файла (с вариантами) (2 балла)
#
# **Подготовка:** Создайте файл `logs.txt` со следующим содержимым:
# ```
# 2023-10-29 10:00:01 INFO: User 'admin' logged in.
# 2023-10-29 10:01:15 INFO: Data processing started.
# 2023-10-29 10:02:30 WARNING: Disk space is running low.
# 2023-10-29 10:03:00 ERROR: Failed to connect to database.
# 2023-10-29 10:05:45 INFO: Data processing finished.
# 2023-10-29 10:06:21 ERROR: Module 'payment' failed with timeout.
# ```
# **Инструкция:** Ваш вариант определяется по формуле `(N - 1) % 4 + 1`.
#
# **Задача:** Напишите программу для анализа этого лог-файла.
# -   **Вариант 1:** Подсчитать и вывести количество записей для каждого уровня ошибок (INFO, WARNING, ERROR).
# -   **Вариант 2:** Вывести на экран только те строки, которые содержат уровень `ERROR`.
# -   **Вариант 3:** Найти и вывести время (в формате `ЧЧ:ММ:СС`) всех событий уровня `WARNING`.
# -   **Вариант 4:** Посчитать, сколько всего событий произошло в 10-м часу (с 10:00:00 по 10:59:59).

# %%
# Ваше решение здесь

# %% [markdown]
# ### Задание 3.9: Работа с CSV-файлом (2 балла)
#
# **Подготовка:** Создайте файл `students.csv` (CSV - Comma-Separated Values) со следующим содержимым:
# ```
# Name,Age,Course
# Ardak,27,3
# Bekarys,23,2
# Aliya,30,4
# ```
# **Задача:** Напишите программу, которая:
# 1. Считывает данные из `students.csv`.
# 2. Запрашивает у пользователя имя, возраст и курс нового студента.
# 3. Добавляет новую запись в конец файла `students.csv`.
# 4. Выводит на экран итоговое содержимое файла.

# %%
# Ваше решение здесь
