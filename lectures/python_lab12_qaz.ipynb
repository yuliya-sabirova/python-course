# %% [markdown]
# # №12 Зертханалық жұмыс: Қорытынды жұмыс
# ## КДТ көмегімен динамикалық жүйелерді модельдеу
#
# **Аты-жөні:** _________________________
#
# **Топ:** _______________________
#
# **Ескерту:** Файл атауы `АТ_топ_зерт12.ipynb` форматында болуы керек.
#
# **Жалпы баға:** 10 балл

# %% [markdown]
# ### Жұмыс мақсаты
#
# Кәдімгі дифференциалдық теңдеулермен (КДТ) сипатталатын динамикалық жүйелерді модельдеуді үйрену. КДТ-ларды шешудің стандартты бағдарламалық тәсілін (аналитикалық және сандық) меңгеру, жүйенің уақыт бойынша мінез-құлқын визуализациялау және алынған нәтижелерді талдау.

# %% [markdown]
# ### Нұсқа нөмірін анықтау
#
# Нұсқа нөмірі сіздің топтағы тізімдегі нөміріңізге сәйкес келеді. Егер топта 13-тен астам адам болса, нұсқа нөмірі келесі формула бойынша есептеледі: `(N - 1) % 13 + 1`, мұндағы `N` — сіздің тізімдегі нөміріңіз.

# %% [markdown]
# ### Нұсқалар кестесі
#
# | № | 1-ретті КДТ | 2-ретті КДТ |
# |:---:|:---|:---|
# | 1 | $y' + 3y = 6$, $y(0) = 2$. | $y'' + 3y' + 2y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 2 | $y' - y = e^t$, $y(0) = 1$. | $y'' - y = 0$, $y(0) = 1, y'(0) = 1$. |
# | 3 | $y' + y \cos(t) = \sin(t)$, $y(0) = 0$. | $y'' + y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 4 | $y' = t^2 - y$, $y(0) = 1$. | $y'' + 2y' + y = 0$, $y(0) = 1, y'(0) = -1$. |
# | 5 | $y' = y \ln(y)$, $y(1) = e$. | $y'' + y' = 0$, $y(0) = 1, y'(0) = -1$. |
# | 6 | $y' + \frac{2}{t}y = t^3$, $y(1) = 0$. | $y'' - 4y' + 4y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 7 | $y' = e^{-t} - y$, $y(0) = 1$. | $y'' + 4y = 0$, $y(0) = 0, y'(0) = 1$. |
# | 8 | $y' + 2y = t^2$, $y(0) = 1$. | $y'' - 3y' + 2y = e^t$, $y(0) = 0, y'(0) = 1$. |
# | 9 | $y' = y^2 - 2y + 1$, $y(0) = 1$. | $y'' + y = \cos(t)$, $y(0) = 0, y'(0) = 1$. |
# | 10 | $y' - 3y = t$, $y(0) = 0$. | $y'' + 2y' + 5y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 11 | $y' = 1 + y^2$, $y(0) = 0$. | $y'' + y' - 6y = t$, $y(0) = 1, y'(0) = -1$. |
# | 12 | $y' + y = e^t$, $y(0) = 0$. | $y'' - t^2y = 0$, $y(0) = 1, y'(0) = 0$. |
# | 13 | $y' = y \sin(t)$, $y(0) = 1$. | $y'' + 5y' + 6y = \sin(t)$, $y(0) = 0, y'(0) = 1$. |

# %% [markdown]
# ---

# %% [markdown]
# ## 1-тапсырма: Нұсқа бойынша КДТ-ны шешу және талдау (4 балл)
#
# Бұл тапсырмада нұсқаңыздағы екі теңдеуді де (бірінші және екінші ретті) екі тәсілмен шешіп, нәтижелерін салыстыру қажет.

# %% [markdown]
# ### 1.1. Бірінші ретті КДТ (2 балл)
#
# 1.  **Аналитикалық шешім:** `sympy.dsolve` көмегімен нақты шешімді табыңыз.
# 2.  **Сандық шешім:** `scipy.integrate.solve_ivp` көмегімен `t` уақыт аралығы 0-ден 5-ке дейінгі аралықта сандық шешімді табыңыз.
# 3.  **Визуализация:** Бір графикте аналитикалық (сызық түрінде) және сандық (нүктелер түрінде) шешімдерді салыңыз. Графиктің атауы, өстерінің белгілері және легендасы болуы керек.
# 4.  **Қорытынды:** Шешімдердің сәйкестігі туралы қысқаша қорытынды жасаңыз.

# %%
# 1.1-тапсырмаға арналған сіздің кодыңыз

# %% [markdown]
# **1.1-тапсырма бойынша қорытынды:**
#
# *(бұл жерде сіздің мәтіндік қорытындыңыз)*

# %% [markdown]
# ### 1.2. Екінші ретті КДТ (2 балл)
#
# 1.  **Түрлендіру:** Екінші ретті КДТ-ны қолмен бірінші ретті екі КДТ-дан тұратын жүйеге айналдырыңыз. Бұл жүйені төмендегі мәтіндік ұяшыққа жазыңыз.
# 2.  **Аналитикалық шешім:** `sympy.dsolve` көмегімен бастапқы теңдеудің нақты шешімін табыңыз.
# 3.  **Сандық шешім:** Алынған жүйені `scipy.integrate.solve_ivp` көмегімен `t` уақыт аралығы 0-ден 10-ға дейінгі аралықта шешіңіз.
# 4.  **Визуализация:** Бір графикте `y(t)` үшін аналитикалық және сандық шешімдерді салыңыз.
# 5.  **Қорытынды:** Шешімдердің сәйкестігі туралы қысқаша қорытынды жасаңыз.

# %% [markdown]
# **Сіздің бірінші ретті КДТ жүйеңіз:**
# $$ \begin{cases} y_1' = ... \\ y_2' = ... \end{cases} $$

# %%
# 1.2-тапсырмаға арналған сіздің кодыңыз

# %% [markdown]
# **1.2-тапсырма бойынша қорытынды:**
#
# *(бұл жерде сіздің мәтіндік қорытындыңыз)*

# %% [markdown]
# ---

# %% [markdown]
# ## 2-тапсырма: Сандық әдісті зерттеу (3 балл)
#
# Бұл тапсырмада сіз `solve_ivp` шешушісінің жұмысын тереңірек зерттейсіз.

# %% [markdown]
# ### 2.1. Шешушілерді салыстыру (1.5 балл)
#
# 1.  1.2-тапсырмадағы екінші ретті КДТ-ңызды алыңыз.
# 2.  Оны `solve_ivp` көмегімен екі рет, әртүрлі әдістерді қолданып шешіңіз: `method='RK45'` (әдепкі бойынша қолданылады) және `method='LSODA'` ("қатаң" жүйелерге жақсы).
# 3.  Екі сандық шешімді де бір графикте салыңыз.
# 4.  **Сұрақтарға жауап беріңіз:** Көзбен қарағанда, сіздің есебіңіз үшін нәтижелерде айырмашылық бар ма? Қандай жағдайларда әдісті таңдау өте маңызды болуы мүмкін?

# %%
# 2.1-тапсырмаға арналған сіздің кодыңыз

# %% [markdown]
# **2.1-тапсырма бойынша сұрақтарға жауаптар:**
#
# *(бұл жерде сіздің жауаптарыңыз)*

# %% [markdown]
# ### 2.2. Қателікті бағалау (1.5 балл)
#
# 1.  Екінші ретті (немесе қалауыңыз бойынша бірінші ретті) КДТ-ңыз үшін сандық шешім табылған әрбір нүктеде сандық шешім (`RK45` әдісімен алынған) мен аналитикалық шешім арасындағы **абсолютті қателікті** есептеңіз.
# 2.  Осы қателіктің уақытқа `t` тәуелділігінің графигін салыңыз.
# 3.  **Сұраққа жауап беріңіз:** Уақыт аралығының қай бөлігінде қателік максималды? Сіздің ойыңызша, бұл неліктен болады?

# %%
# 2.2-тапсырмаға арналған сіздің кодыңыз

# %% [markdown]
# **2.2-тапсырма бойынша сұраққа жауап:**
#
# *(бұл жерде сіздің жауабыңыз)*

# %% [markdown]
# ---

# %% [markdown]
# ## 3-тапсырма: Қолданбалы есеп — Физикалық жүйені модельдеу (3 балл)
#
# Бұл КДТ-ның қуатын көрсететін шығармашылық, қорытынды тапсырма. Ұсынылған есептердің **біреуін** таңдап, шешіңіз.

# %% [markdown]
# ### 1-нұсқа: "Жыртқыш-Жем" моделі (Лотка-Вольтерра теңдеулері)
#
# Жүйе екі түрдің популяцияларының динамикасын сипаттайды: жемдер (`x`) және жыртқыштар (`y`).
# $$ \begin{cases} dx/dt = a*x - b*x*y \\ dy/dt = -c*y + d*x*y \end{cases} $$
#
# - **Параметрлер:** `a=1.5, b=0.8, c=1.0, d=0.5`.
# - **Бастапқы шарттар:** `x(0) = 2` (2 мың жем), `y(0) = 1` (1 мың жыртқыш).
#
# **Не істеу керек:**
# 1.  Осы КДТ жүйесін `t` уақыт аралығы 0-ден 20-ға дейін шешіңіз.
# 2.  `x(t)` және `y(t)` популяцияларының уақыт бойынша өзгеруін көрсететін график салыңыз (бір графикте екі қисық).
# 3.  **Фазалық портрет** салыңыз: жыртқыштар популяциясының жемдер популяциясына тәуелділігінің графигі (`y`-тің `x`-ке тәуелділігі).
# 4.  **Түсіндірме:** Мәтіндік ұяшықта бұл графиктер нені көрсететінін өз сөзіңізбен сипаттаңыз. Неліктен популяциялар тербеледі?

# %% [markdown]
# ### 2-нұсқа: Маятниктің өшетін тербелістері моделі
#
# Ауа кедергісін ескеретін маятниктің сызықтандырылған қозғалыс теңдеуі:
# $$ \theta'' + 2\gamma\theta' + \omega^2\theta = 0 $$
# мұндағы `θ` - ауытқу бұрышы.
#
# - **Параметрлер:** `ω = 2.0` (меншікті жиілік), `γ = 0.2` (өшу коэффициенті).
# - **Бастапқы шарттар:** `θ(0) = π/6` (бастапқы бұрыш 30 градус), `θ'(0) = 0` (бастапқы жылдамдық нөлге тең).
#
# **Не істеу керек:**
# 1.  Осы екінші ретті КДТ-ны бірінші ретті КДТ жүйесіне айналдырыңыз.
# 2.  Жүйені `t` уақыт аралығы 0-ден 15-ке дейін шешіңіз.
# 3.  `θ(t)` бұрышының уақытқа тәуелділік графигін салыңыз.
# 4.  **Фазалық портрет** салыңыз: `θ'(t)` бұрыштық жылдамдығының `θ(t)` бұрышына тәуелділік графигі.
# 5.  **Түсіндірме:** Мәтіндік ұяшықта алынған графиктерге сүйене отырып, өшу маятниктің қозғалысына қалай әсер ететінін сипаттаңыз. Фазалық портрет нені көрсетеді?

# %%
# 3-тапсырмаға арналған сіздің кодыңыз (нұсқалардың бірін таңдаңыз)

# %% [markdown]
# **3-тапсырма нәтижелерінің түсіндірмесі:**
#
# *(бұл жерде сіздің мәтіндік қорытындыңыз)*
